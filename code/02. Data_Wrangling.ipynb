# %% [markdown]
# # 패키지 불러오기

# %%
import pandas as pd
import numpy as np
import os
import glob
import gc

# %% [markdown]
# # 중극장 데이터 불러오기

# %%
df = pd.read_parquet("data/Medium_Theater.parquet")

# %% [markdown]
# ## 년도_월, 년도_월_일 컬럼 만들기

# %%
# 년도_월, 년도_월_일 컬럼
df["년도_월"] = df["공연일시"]
df["년도_월"] = df["년도_월"].apply(lambda x : x[0:4]+x[5:7])

df["년도_월_일"] = df["공연일시"]
df["년도_월_일"] = df["년도_월_일"].apply(lambda x : x[0:4]+x[5:7]+x[8:10])

# %%
df = df.astype({'년도_월':'int'})
df = df.astype({'년도_월_일':'int'})

# %% [markdown]
# ## 년도, 월, 일, 요일 컬럼 만들기

# %%
df["공연일시"] = pd.to_datetime(df["공연일시"])
df["예매/취소일시"] = pd.to_datetime(df["예매/취소일시"])

# %%
df["년도"] = df["공연일시"].dt.year
df["월"] = df["공연일시"].dt.month
df["일"] = df["공연일시"].dt.day
df["요일"] = df["공연일시"].dt.day_name()

# %% [markdown]
# ## 공연일시보다 예매일시가 늦은 경우 삭제

# %%
df[df["공연일시"] < df["예매/취소일시"]][["공연일시", "예매/취소일시"]]
# Out:
#                        공연일시             예매/취소일시
# 99      2019-07-06 14:00:00 2019-07-06 14:09:00
# 101     2019-07-06 14:00:00 2019-07-06 14:09:00
# 329     2019-07-06 17:00:00 2019-07-10 17:44:00
# 330     2019-07-06 17:00:00 2019-07-10 17:44:00
# 331     2019-07-06 17:00:00 2019-07-10 17:44:00
# ...                     ...                 ...
# 4754897 2022-12-31 21:00:00 2022-12-31 21:33:00
# 4754898 2022-12-31 21:00:00 2022-12-31 21:33:00
# 4754899 2022-12-31 21:00:00 2022-12-31 21:32:00
# 4754900 2022-12-31 21:00:00 2022-12-31 21:32:00
# 4754901 2022-12-31 21:00:00 2022-12-31 21:32:00
#
# [89883 rows x 2 columns]

# %%
idx = df[df["공연일시"] < df["예매/취소일시"]][["공연일시", "예매/취소일시"]].index
len(idx)
# Out:
# 89883

# %%
df = df.drop(idx, axis=0)
df = df.reset_index(drop=True)

# %% [markdown]
# ## 중복데이터 삭제

# %%
temp = df[df.duplicated(['입장권고유번호', '전송사업자명'], keep=False)].sort_values(by = ['입장권고유번호', '예매/취소일시'])
gb_temp = temp.groupby("입장권고유번호").sum()["예매/취소구분"]
gb_temp
# Out:
# 입장권고유번호
# 0000782754        2
# 0000782756        2
# 0000782807        2
# 0000782809        2
# 0000782811        2
#                  ..
# W2298902870002    3
# W2299434270001    3
# W2299434270002    3
# W2299635419001    3
# W2299635419002    3
# Name: 예매/취소구분, Length: 831550, dtype: int64

# %%
# 가장 뒤에 데이터만 살리고 앞의 데이터 모두 지우기
df = df.sort_values(by = ['공연일시', '예매/취소일시']).reset_index(drop=True)
df = df.drop_duplicates(['입장권고유번호', '전송사업자명'], keep='last')
df
# Out:
#            공연시설코드  전송사업자명      공연코드 공연지역명                          주소  좌석수  \
# 0        FC222305    인터파크  PF372107   경상도  대구광역시 달서구 문화회관길 160 (장기동)   455
# 1        FC222305    인터파크  PF372107   경상도  대구광역시 달서구 문화회관길 160 (장기동)   455
# 2        FC222305    인터파크  PF372107   경상도  대구광역시 달서구 문화회관길 160 (장기동)   455
# 3        FC222305    인터파크  PF372107   경상도  대구광역시 달서구 문화회관길 160 (장기동)   455
# 4        FC222305    인터파크  PF372107   경상도  대구광역시 달서구 문화회관길 160 (장기동)   455
# ...           ...     ...       ...   ...                         ...  ...
# 4666011  FC222768  영천시민회관  PF425870   경상도      경상북도 영천시 시청로 17 (문외동)   799
# 4666012  FC222768  영천시민회관  PF425870   경상도      경상북도 영천시 시청로 17 (문외동)   799
# 4666013  FC222768  영천시민회관  PF425870   경상도      경상북도 영천시 시청로 17 (문외동)   799
# 4666014  FC222768  영천시민회관  PF425870   경상도      경상북도 영천시 시청로 17 (문외동)   799
# 4666015  FC222768  영천시민회관  PF425870   경상도      경상북도 영천시 시청로 17 (문외동)   799
#
#                        공연일시             예매/취소일시      입장권고유번호  예매/취소구분  ...  \
# 0       2019-07-01 15:00:00 2019-06-28 23:22:00  T0882670981        1  ...
# 1       2019-07-01 15:00:00 2019-06-28 23:22:00  T0882670982        1  ...
# 2       2019-07-01 15:00:00 2019-06-28 23:22:00  T0882670983        1  ...
# 3       2019-07-01 15:00:00 2019-06-28 23:22:00  T0882670984        1  ...
# 4       2019-07-01 15:00:00 2019-06-28 23:22:00  T0882670985        1  ...
# ...                     ...                 ...          ...      ...  ...
# 4666011 2022-12-31 21:50:00 2022-12-30 17:59:00       473341        1  ...
# 4666012 2022-12-31 21:50:00 2022-12-30 22:48:00       473348        1  ...
# 4666013 2022-12-31 21:50:00 2022-12-30 22:48:00       473350        1  ...
# 4666014 2022-12-31 21:50:00 2022-12-30 22:48:00       473351        1  ...
# 4666015 2022-12-31 21:50:00 2022-12-30 22:48:00       473352        1  ...
#
#          장당금액   장르명 세부장르명       좌석등급    년도_월    년도_월_일    년도   월   일        요일
# 0           0   뮤지컬   뮤지컬    전석무료(0)  201907  20190701  2019   7   1    Monday
# 1           0   뮤지컬   뮤지컬    전석무료(0)  201907  20190701  2019   7   1    Monday
# 2           0   뮤지컬   뮤지컬    전석무료(0)  201907  20190701  2019   7   1    Monday
# 3           0   뮤지컬   뮤지컬    전석무료(0)  201907  20190701  2019   7   1    Monday
# 4           0   뮤지컬   뮤지컬    전석무료(0)  201907  20190701  2019   7   1    Monday
# ...       ...   ...   ...        ...     ...       ...   ...  ..  ..       ...
# 4666011  5000  대중음악  대중가요  전석(10000)  202212  20221231  2022  12  31  Saturday
# 4666012  5000  대중음악  대중가요  전석(10000)  202212  20221231  2022  12  31  Saturday
# 4666013  5000  대중음악  대중가요  전석(10000)  202212  20221231  2022  12  31  Saturday
# 4666014  5000  대중음악  대중가요  전석(10000)  202212  20221231  2022  12  31  Saturday
# 4666015  5000  대중음악  대중가요  전석(10000)  202212  20221231  2022  12  31  Saturday
#
# [3794063 rows x 30 columns]

# %% [markdown]
# ## 입장권고유번호 기준으로 예매건수보다 취소건수가 많은 경우 삭제

# %%
# 입장권 고유번호를 기준으로 예매/취소 건수를 카운트
df["예매건수"] = ""
df["취소건수"] = ""

def TicketingCount(x):
    if x == 1:
        return 1
    else:
        return 0
    
def CancleCount(x):
    if x == 2:
        return 1
    else:
        return 0
    
df["예매건수"] = df["예매/취소구분"].apply(lambda x : TicketingCount(x))
df["취소건수"] = df["예매/취소구분"].apply(lambda x : CancleCount(x))

# %%
temp = df.groupby(["입장권고유번호", "전송사업자명"]).sum()[["예매건수", "취소건수"]]
len(temp)
# Out:
# 3794063

# %%
# 예매건수보다 취소건수가 많은 데이터 제거하기
temp[temp["예매건수"] < temp["취소건수"]]
# Out:
#                           예매건수  취소건수
# 입장권고유번호        전송사업자명
# 0003025700RDPT 티몬            0     1
# 0012930486     문화N티켓         0     1
# 0012930508     문화N티켓         0     1
# 0012930584     문화N티켓         0     1
# 0013030597     문화N티켓         0     1
# ...                        ...   ...
# W2299635419002 위메프           0     1
# W2299759870001 국립아시아문화전당     0     1
# W2299815157001 국립아시아문화전당     0     1
# W2299972214001 국립아시아문화전당     0     1
# W2299972214002 국립아시아문화전당     0     1
#
# [840719 rows x 2 columns]

# %%
idx = temp[temp["예매건수"] < temp["취소건수"]].index
len(idx)
# Out:
# 840719

# %%
df["입장권고유번호제거"] = df["입장권고유번호"].apply(lambda x : 0 if x in idx else x)
idx = df[df["입장권고유번호제거"]==0].index

# %%
df = df.drop(idx, axis=0)
df = df.reset_index(drop=True)

# %%
df = df.drop("입장권고유번호제거", axis=1)

# %% [markdown]
# ## 공연시설코드는 같은데, 주소가 다른경우 하나로 수정

# %%
code = df["공연시설코드"].unique()
code
# Out:
# array(['FC222305', 'FC222397', 'FC222759', 'FC222691', 'FC223203',
#        'FC223304', 'FC222630', 'FC222389', 'FC222318', 'FC223890',
#        'FC222739', 'FC222426', 'FC222298', 'FC222054', 'FC222382',
#        'FC223391', 'FC222593', 'FC222049', 'FC223390', 'FC222058',
#        'FC222677', 'FC223320', 'FC222898', 'FC222669', 'FC222642',
#        'FC222076', 'FC223307', 'FC223835', 'FC222570', 'FC222768',
#        'FC223637', 'FC222422', 'FC222637', 'FC222390', 'FC222661',
#        'FC222048', 'FC223518', 'FC222099', 'FC222542', 'FC222080',
#        'FC223485', 'FC223055', 'FC222629', 'FC222760', 'FC222912',
#        'FC223012', 'FC223492', 'FC222463', 'FC222984', 'FC223510',
#        'FC223505', 'FC222983', 'FC223418', 'FC222203', 'FC223470',
#        'FC223561', 'FC223478', 'FC222415', 'FC223807', 'FC222096',
#        'FC222979', 'FC223464', 'FC222455', 'FC222587', 'FC223584',
#        'FC222280', 'FC222613', 'FC222628', 'FC223628', 'FC223194',
#        'FC222663', 'FC222597', 'FC222615', 'FC222091', 'FC223540',
#        'FC224206', 'FC223622', 'FC222567', 'FC223388', 'FC222659',
#        'FC222545', 'FC222933', 'FC222699', 'FC222651', 'FC223838',
#        'FC223520', 'FC223098', 'FC223812', 'FC223795', 'FC222450',
#        'FC223641', 'FC222061', 'FC222606', 'FC222641', 'FC222458',
#        'FC222386', 'FC223897', 'FC223493', 'FC224388', 'FC223315',
#        'FC222619', 'FC222146', 'FC222653', 'FC222409', 'FC222151',
#        'FC222667', 'FC223414', 'FC222693', 'FC222655', 'FC222657',
#        'FC223931', 'FC223941', 'FC222737', 'FC223776', 'FC222747',
#        'FC222707', 'FC222093', 'FC223313', 'FC223544', 'FC223909',
#        'FC222952', 'FC224337', 'FC222771', 'FC223758', 'FC223114',
#        'FC223392', 'FC224308', 'FC222634', 'FC222206', 'FC222007',
#        'FC222982', 'FC222472', 'FC222040', 'FC222665', 'FC222469',
#        'FC222778', 'FC222697', 'FC224306', 'FC223654', 'FC222120',
#        'FC224381', 'FC222646', 'FC222388', 'FC224467', 'FC223730',
#        'FC223309', 'FC222685', 'FC222603', 'FC222968', 'FC222272',
#        'FC222965', 'FC223590', 'FC224432', 'FC223889', 'FC222802',
#        'FC223711', 'FC223816', 'FC222800', 'FC222466', 'FC224486',
#        'FC224454', 'FC224485', 'FC223419', 'FC222741', 'FC222964',
#        'FC223906', 'FC222564', 'FC224496', 'FC224535', 'FC224554',
#        'FC222488', 'FC224550', 'FC224581', 'FC222627', 'FC223624',
#        'FC222622', 'FC222577', 'FC223086', 'FC223028', 'FC224622',
#        'FC222075', 'FC222849', 'FC224494', 'FC224571', 'FC222089',
#        'FC223563', 'FC224840', 'FC224898', 'FC222706', 'FC223312',
#        'FC224848', 'FC224954', 'FC223821', 'FC224704', 'FC222648',
#        'FC224981', 'FC224991', 'FC224024', 'FC222087', 'FC224684',
#        'FC222090', 'FC223381', 'FC222973', 'FC223317', 'FC223559',
#        'FC224144', 'FC223314', 'FC222275', 'FC223528', 'FC225234',
#        'FC222282', 'FC223658', 'FC222006', 'FC225265', 'FC222790',
#        'FC224605', 'FC225327', 'FC223975', 'FC222846', 'FC225373',
#        'FC222475', 'FC222574'], dtype=object)

# %%
# 공연시설코드값을 돌리면서 주소의 고유값을 리스트로 리스트에 담기
def AdressCheck(df, code):
    adress = []
    for i in code:
        ad = df[df["공연시설코드"] == i]["주소"].unique()
        adress.append(list(ad))
    return adress
adress = AdressCheck(df, code)

# %%
len(adress)
# Out:
# 222

# %%
for i in range(len(adress)):
    if len(adress[i]) >= 2:
        print(i)

# %% [markdown]
# ## 무료공연 유료공연 구분

# %%
# 전석무료(0), 전석(0), A석(0), 현장판매(0), A석 전석소외계층초청(0), '전석무료(0), 전석무료(0)'
df["좌석등급"].unique()
# Out:
# array(['전석무료(0)', '전석(20000)', '전석(10000)', 'R석(30000), S석(20000)', None,
#        '전석(12000)', '전석(5000)', 'VIP석(40000), R석(30000), A석(20000)',
#        '전석(30000)', 'R석(70000), S석(50000), A석(30000)', '전석(40000)',
#        '전석(35000)', 'R석(55000)', '전석(25000)', 'VIP석(5000), 일반석(4000)',
#        'R석(15000), S석(10000)', 'R석(40000), S석(30000), A석(20000)',
#        '전석(77000)', 'R석(20000), S석(10000)', '일반석(25000), 사이드석(10000)',
#        'R석(50000), S석(30000), A석(20000)', '전석(15000)',
#        '1층석(10000), 2층석(5000)', 'R석(6000), S석(5000), A석(4000)',
#        'R석(50000), S석(30000)', '1층석(15000), 2층석(11000)', '전석(50000)',
#        'R석(20000), S석(15000)', 'J석(40000), R석(35000), S석(25000)',
#        'R석(66000), S석(44000)', '1층 R석(30000), 2층 S석(24000)', '전석(24000)',
#        'R석(30000), S석(20000), A석(10000)',
#        'R석(50000), S석(30000), A석(20000), B석(10000)',
#        '비지정R석(50000), 비지정S석(30000), 비지정A석(20000), 비지정B석(10000)',
#        'R석(110000), S석(99000), A석(88000)', 'A석(10000), C석(5000)',
#        '전석(3000)', '1층석(7000), 2층석(5000)', '전석(7000)',
#        'VIP석(143000), R석(121000), A석(99000), B석(66000)',
#        'R석(55000), S석(45000)', '전석(44000)',
#        'VIP석(45000), R석(35000), S석(25000)', 'S석(20000), A석(10000)',
#        '전석(99000)', 'VIP석(20000), 일반석(15000)', 'VIP석(88000), R석(77000)',
#        '1층석(99000), 2층석(77000)', '전석(1000)', '일반석(3000), 청소년석(1500)',
#        'VIP석(35000), R석(25000), S석(15000)', '1층석(10000), 2층석(7000)',
#        'VIP석(60000), R석(50000)', 'R석(90000), S석(70000)',
#        'R석(5000), S석(3000), A석(2000)', 'R석(75000), S석(55000)',
#        '1층석(5000)', '전석(2000)', 'VIP석(70000), R석(50000), S석(30000)',
#        '전석(6000)', 'R석(17500), S석(15000)',
#        'R석(60000), S석(50000), A석(40000)', 'R석(60000), S석(40000)',
#        '전석(8000)', 'R석(70000), S석(50000)', '1층석(7000)', '전석(18000)',
#        '양일권(49500), 일일권(27500)', 'VIP석(90000), R석(70000), S석(50000)',
#        '전석(55000)', 'R석(30000)', '1일권(10000), 2일권(15000)',
#        'VIP석(30000), 일반석(25000)', 'R석(50000), S석(30000), A석(10000)',
#        'R석(10000), S석(5000)', 'R석(10000), S석(8000), A석(6000)',
#        'S석(10000), A석(8000)', '1층석(15000), 2층석(10000)',
#        'R석(60000), S석(44000)', 'S석(10000), A석(5000)',
#        'VIP석(45000), R석(35000)', '2층석(10000), 3층석(10000)',
#        'R석(50000), A석(20000)', '현장판매(0)',
#        'M석_1인석(10000), C석_2인 테이블(20000), F석_4인 테이블(30000)',
#        'R석(100000), S석(70000)', 'R석(10000), S석(7000)',
#        'R석(20000), A석(10000)', '1층석(35000), 2층석(25000)',
#        '1층석(20000), 2층석(15000)', 'VIP석(50000), R석(30000), S석(20000)',
#        'S석(40000), A석(20000)', 'R석(88000), S석(77000), A석(66000)',
#        'R석(50000), S석(40000), A석(30000)', 'VIP석(10000)',
#        'R석(70000), S석(60000)', 'VIP석(50000), R석(40000)', '전석(100)',
#        'R석(20000), S석(15000), A석(10000)', 'S석(20000)',
#        'VIP석(100000), R석(50000), S석(30000)',
#        'VIP석(140000), R석(130000), S석(110000), A석(80000), B석(60000)',
#        '1층석(30000), 2층석(20000)', 'R석(44000), S석(33000)',
#        'R석(40000), S석(33000)', '전석(45000)',
#        'R석(70000), S석(45000), A석(30000)', 'VIP석(6000), 일반석(5000)',
#        'A석(10000)', 'VIP석(20000), R석(15000), S석(10000), A석(0)',
#        '전석(16000)', '일반(3000), 청소년(1500)', '1층석(15000), 2층석(12000)',
#        'S석(5000)', 'VIP석(55000), R석(45000)', 'R석(40000), S석(30000)',
#        'S석(5000), A석(0)', '전석(6600)', '전석(0)', 'A석(10000), B석(5000)',
#        'R석(35000), S석(30000)', '일반(6000), 학생(4000)',
#        'R석(50000), S석(40000)', '전석(4000)', 'VIP석(30000), 일반(25000)',
#        '월드그레이트매직쇼 R석(30000), 월드그레이트매직쇼 S석(25000), 월드그레이트매직쇼 A석(20000), 국제마술대회 R석(20000), 국제마술대회 S석(15000), 국제마술대회 A석(10000)',
#        'R석(120000), S석(100000), A석(70000), B석(30000)',
#        'VIP석(50000), R석(20000), S석(15000)', '1층석(5000), 2층석(3000)',
#        '1층석(20000), 2층석(10000)', 'J석(40000), R석(35000), 2층석(25000)',
#        'A석(20000)', 'R석(35000), A석(25000)',
#        'R석(95000), A석(65000), B석(40000)', 'R석(55000), S석(50000)',
#        'VIP석(29900), R석(19900)', 'R석(50000), S석(35000)',
#        'S석(20000), A석 전석소외계층초청(0)', 'R석(12000), S석(9000)',
#        'VIP석(77000), R석(55000), S석(33000), A석(22000)',
#        'R석(45000), S석(35000)', '전석(100000)',
#        'R석(10000), S석(8000), A석(6000), 휠체어석(8000)',
#        'R석(35000), S석(25000), A석(15000)', '1층석(8000), 2층석(6000)',
#        'VIP석(40000), R석(30000), S석(20000), A석(10000)',
#        '1층석(45000), 2층석(30000)', '1층석(40000), 2층석(30000)', 'R석(40000)',
#        'R석(99000)', 'R석(99000), S석(88000)', 'VIP석(25000), 일반석(20000)',
#        '전석(33000)', 'R석(10000)', 'VIP석(100000), R석(80000), S석(60000)',
#        '1층석(35000), 2층석(20000)', 'R석(50000), S석(40000), A석(20000)',
#        'R석(44000)', 'C석(12000)', '전석(132000)',
#        'VIP석(120000), R석(70000), S석(50000), A석(30000)',
#        '성인(3000), 학생(1500)', 'R석(40000), S석(20000)',
#        'R석(30000), S석(25000)', 'R석(77000), S석(66000)',
#        '1층석(70000), 2층석(55000)',
#        'R석(50000), S석(40000), A석(30000), 학생할인석(10000)',
#        '1층석(60000), 2층석(50000)', 'R석(60000), S석(50000)', '성인(30000)',
#        'R석(65000), S석(40000), A석(25000)', 'R석(33000), S석(30250)',
#        'R석(30250), S석(27500)', 'R석(50000)',
#        'R석(88000), S석(66000), A석(30000), B석(10000)',
#        'R석(66000), S석(55000)', 'VIP석(20000), S석(10000)',
#        'R석(66000), S석(55000), A석(44000)', 'V석(100000), R석(80000)',
#        'VIP석(50000), R석(30000), A석(20000), B석(10000)',
#        '성인(10000), 청소년(5000)', 'R석(77000), S석(55000)',
#        'VIP석(20000), R석(10000), S석(5000)', '전석(9900)',
#        'R석(35000), S석(25000)', 'R석(99000), S석(77000)',
#        '1층석(50000), 2층석(30000)', 'S석(100000), A석(70000), B석(30000)',
#        'A석(3000)', '전석(9000)', 'VIP석(60000), S석(50000), A석(40000)',
#        'R석(55000), S석(44000), A석(33000)',
#        'VIP석(40000), R석(30000), B석(20000)',
#        'VIP석(100000), R석(80000), S석(50000)',
#        'R석(130000), A석(90000), B석(60000)', 'R석(100000), S석(80000)',
#        'S석(30000), A석(10000)', 'VIP석(121000), R석(110000)',
#        'VIP석(200000), R석(150000)', 'R석(33000), S석(22000)',
#        'R석(85000), A석(65000), B석(40000)', 'VIP석(60000), R석(40000)',
#        '1층석(66000), 2층석(44000)', 'VIP석(60000), R석(50000), S석(30000)',
#        '전석(120000)', '전석(121000)',
#        'R석(66000), S석(55000), A석(44000), B석(33000)',
#        'R석(90000), S석(70000), A석(50000)', 'R석(55000), S석(40000)',
#        '1층석(12000), 2층석(9000)', '전석(66000)',
#        'R석(49000), S석(39000), A석(29000)', '만18세이하(24000), 성인(28000)',
#        '전석(10000), 패키지(15000)', 'R석(25000), S석(15000)',
#        'R석(100000), S석(50000)', 'R석(100000), S석(70000), A석(40000)',
#        'VIP석(200000), R석(100000), S석(50000), A석(30000)',
#        '전석(5000), 전석(5000)', 'R석(60000), S석(40000), A석(20000)',
#        'S석(5000), A석(4000)', '전석무료(0), 전석무료(0)', '1층석(30000), 1층석(20000)',
#        'R석(50000), S석(20000), A석(10000)',
#        'R석(80000), S석(50000), A석(30000)', 'S석(15000), A석(10000)',
#        'VIP석(50000), R석(20000)', 'VIP석(50000), R석(2000)',
#        'R석(80000), S석(60000)', 'R석(15000), S석(10000), A석(5000)',
#        '귀명창석(20000), S석(10000)', 'S석(10000)',
#        '1층석(8000), 2층석(6000), 1층석(8000), 2층석(6000)', '전석(17000)',
#        'VIP석(120000), R석(100000), A석(60000), B석(40000)',
#        'VIP석(50000), R석(30000)', 'VIP석(20000), R석(10000)', 'R석(15000)',
#        '전석(70000)', 'R석(50000), S석(35000), A석(20000)',
#        'VIP석(80000), R석(50000), S석(30000), A석(20000), B석(10000)',
#        '전석(22000)', 'R석(100000), S석(80000), A석(50000)',
#        'R석(20000), S석(15000), A석(10000), B석(5000)', '전석(88000)',
#        'R석(20000), S석(10000), A석(5000)', 'R석(30000), A석(20000)',
#        'R석(40000), S석(30000), A석(10000)', 'R석(132000), S석(121000)',
#        'R석(85000), A석(70000), B석(55000)', 'A석(30000), B석(20000)',
#        '1층석(10000), 2층석(50000)',
#        'VIP석(100000), R석(50000), S석(30000), A석(10000)',
#        'R석(15000), S석(10000), A석(7000)', 'VIP석(55000), R석(35000)',
#        'VIP석(110000), R석(88000), S석(66000)',
#        'R석(30000), S석(20000), A석(10000), B석(5000)',
#        'R석(70000), S석(50000), A석(20000)',
#        'R석(70000), S석(60000), A석(40000)', '전석(19800)',
#        'R석(50000), S석(20000)', '전석(27000)', 'R석(49000), S석(39000)',
#        'VIP석(99000), R석(88000)', 'R석(65000), S석(50000), A석(35000)',
#        'S석(10000), A석(80000)', 'R석(60000), S석(50000), A석(30000)',
#        '동동이석(50000)', 'VIP석(40000), R석(30000), S석(20000)',
#        'S석(5000), A석(3000)',
#        'R석(100000), S석(80000), A석(50000), B석(30000)',
#        'R석(30000), S석(25000), A석(20000)',
#        'VIP석(30000), R석(25000), S석(15000), A석(10000)',
#        'R석(100000), S석(80000), A석(60000)',
#        'R석(59000), S석(49000), A석(39000)',
#        'R석(80000), S석(60000), A석(40000)',
#        'All pass(100000), Light(80000)', '1층석(77000), 2층석(44000)',
#        '1층 R석(10000), 2층 S석(5000)',
#        'VIP석(100000), R석(70000), S석(50000), A석(30000)',
#        '동동이석(50000), 구슬이석(40000)', 'VIP석(100000)', 'VIP석(154000)',
#        'R석(20000)', 'R석(10000), S석(7000), A석(5000)',
#        'R석(65000), S석(55000), A석(40000)', '1층석(45000), 2층석(35000)',
#        'R석(5000)', '1층석(10000)', 'R석(55000), S석(44000)',
#        '사전예약(15000), 현장판매(20000)', 'R석(30000), S석(10000)',
#        'R석(55000), S석(33000)',
#        'VIP석(140000), R석(100000), S석(70000), A석(50000)',
#        'R석(80000), R석(60000)', '전석(18900)',
#        'VIP석(30000), R석(20000), S석(10000)',
#        'R석(70000), A석(55000), B석(40000)', '전석(13000)',
#        'All(240000), 장A(168000), 장B(96000)',
#        'R석(120000), S석(80000), A석(50000), B석(30000)',
#        'VIP석(60000), R석(50000), S석(40000), A석(30000)', '사전예약(19800)',
#        'R석(50000), S석(30000), A석(15000)',
#        'VIP석(130000), R석(110000), S석(90000), A석(70000)', '1층석(20000)',
#        'R석(70000), S석(60000), 시야방해 S석(51000)', '1층석(20000), 2층석(17000)',
#        'R석(80000), S석(50000)', 'VIP석(40000), R석(35000), S석(25000)',
#        'R석(110000), S석(90000), A석(50000)', '전석(30000), 사전예약(20000)',
#        '1층석(55000), 2층석(33000)', '전석(25000), 사전예약(15000)',
#        'VIP석(50000), R석(40000), S석(20000)', '1층석(55000), 2층석(35000)',
#        'VIP석(140000), R석(110000), S석(70000)', '사전예약(15000)',
#        '사전예약(20000)', '1층석(5000), 2층석(4000)',
#        '1층석(30000), 2층석(20000), 3층석(20000)', 'R석(30000), A석(25000)',
#        'V석(70000), R석(50000), S석(30000)', '전석(50000), 사전예약(25000)',
#        'R석(70000), A석(50000), B석(30000)', 'R석(30000), 사전예약(20000)',
#        'R석(30000), S석(20000), A석(10000), 휠체어석(15000)',
#        'VIP석(110000), R석(99000)', '2층석(10000)', '전석(60000)',
#        'R석(90000), S석(80000)', '1층석(30000), 2층석(25000)', 'VIP석(15000)',
#        '전석(30000), 사전예약(18000)', '1층석(50000), 2층석(40000)',
#        'R석(33000), S석(28000)', 'VIP석(66000), R석(55000)',
#        '전석(40000), 사전예약(25000)', 'R석(88000), S석(66000), A석(44000)',
#        'VIP석(132000), R석(121000)', '전석(40000), 사전예약(20000)',
#        '전석(25000), 사전예약(20000)', 'R석(45000), S석(30000)',
#        'R석(50000), S석(45000)', '전석(80000)',
#        'VIP석(150000), R석(130000), S석(100000)', 'VIP석(120000), R석(100000)',
#        'VIP석(130000), R석(110000), S석(90000), A석(60000)',
#        '1층석(66000), 2층석(55000)', '사전예약(27000)',
#        'R석(80000), S석(60000), A석(40000), B석(20000)',
#        'R석(143000), R석(121000)', '어린이(10000), 어른(5000)',
#        'VIP석(132000), R석(110000)', 'R석(143000), S석(121000)',
#        'R석(65000), S석(50000), A석(40000)', 'R석(60000), S석(55000)',
#        '전석(30000), 사전예약(22000)', 'VIP석(15000), R석(10000)',
#        'R석(40000), A석(30000)', '전석(35000), 사전예약(22000)',
#        'R석(50000), S석(40000), A석(30000), B석(20000)', 'R석(6000), S석(6000)',
#        'A석(5000)', 'R석(90000), A석(70000), B석(55000)',
#        'R석(130000), S석(110000), A석(90000), Dream석(30000)', 'R석(35000)',
#        'R석(110000), S석(90000), A석(60000)', 'S석(10000), A석(10000)',
#        '전석(25000), 사전예약(18000)', 'R석(35000), S석(3000)',
#        'R석(143000), S석(121000), A석(110000)', '사전예약(18900)',
#        'R석(70000), A석(50000), B석(40000)', '1층석(55000), 2층석(44000)',
#        'R석(10000), R석(5000)', '사전예약(30000), 현장판매(35000)',
#        'VIP석(50000), R석(20000), S석(10000)',
#        'R석(150000), S석(120000), A석(90000)',
#        'VIP석(70000), R석(50000), S석(20000)',
#        'VIP석(80000), R석(50000), S석(30000)', 'R석(70000)',
#        'V석(70000), R석(50000), S석(30000), A석(10000)',
#        'R석(25000), S석(22000)', '전석(43000)',
#        'R석(20000), S석(10000), 휠체어석(10000)', '예약금(3000)',
#        'R석(10000), S석(6000)', '1층석(44000), 2층석(33000)',
#        'VIP석(30000), R석(20000), A석(10000)',
#        'S석(50000), A석(30000), B석(20000)',
#        'R석(10000), S석(8000), A석(6000), 휠체어석(4000)',
#        'VIP석(30000), 일반석(20000)', 'R석(30000), S석(15000)', '1층석(50000)',
#        'R석(88000), S석(66000)',
#        'R석(30000), S석(20000), A석(10000), 휠체어석(10000)', 'R석(77000)',
#        '1층석(70000), 2층석(40000)', 'R석(10000), S석(10000), A석(5000)',
#        'R석(140000), S석(110000)',
#        'R석(30000), S석(20000), A석(10000), 2층석(5000)',
#        'R석(40000), S석(30000), A석(15000)', 'R석(5000), S석(3000)',
#        'S석(70000), A석(50000), B석(30000)', 'R석(7000), S석(7000), A석(5000)',
#        'VIP석(77000), R석(66000), S석(55000)', 'R석(40000), S석(35000)',
#        '2층석(60000), 3층석(50000)', 'R석(55000), A석(40000), B석(30000)',
#        'VIP석(77000), R석(66000), S석(55000), A석(44000)',
#        '1층석(20000), 2층석(20000)', 'VIP석(100000), R석(70000), S석(50000)',
#        'VIP석(70000), R석(50000)',
#        'VIP석(50000), R석(40000), S석(30000), A석(20000)', 'R석(60000)',
#        'R석(88000), S석(77000)', '전석(14000)', '1층석(30000), 2층석(18000)',
#        'R석(10000), S석(10000), A석(7000)',
#        'VIP석(120000), R석(80000), S석(40000), A석(20000)',
#        'R석(95000), A석(75000), B석(60000)', 'S석(70000), A석(60000)',
#        'R석(100000), S석(70000), A석(50000)', '현장판매(40000), 사전예약(35000)',
#        '1층석(55000), 2층석(45000)',
#        'VIP석(150000), R석(120000), S석(100000), A석(70000), B석(50000), C석(30000)',
#        '전석(37500)', '사전예약(30000)', 'R석(70000), S석(60000), A석(50000)',
#        'VIP석(60000), R석(40000), S석(30000)', 'R석(80000), S석(70000)',
#        'R석(45000), S석(40000)', 'R석(110000), S석(99000), A석(77000)',
#        'R석(85000), S석(65000), A석(45000)',
#        'R석(100000), S석(70000), A석(50000), B석(30000)'], dtype=object)

# %%
# 없음
df["할인종류명(관리시스템)"].unique()
# Out:
# array(['기타', '자체할인', '신용카드사', '다중할인'], dtype=object)

# %%
# 초대권, 초대, 유료회원할인 100%, 무료 공연 할인 100%, , 송년음악회 할인 0원

# 초대권 100%, 전석초대(신나는오케스트라) 0원, 송년음악회 할인 0원, 무료 공연 할인 100%, 유료회원할인 100%
# 유료회원 할인 100%, 초대, 초대권, 직원초대, 초대 100%, 패키지 할인권 100%, 무료공연 할인 100%
# 수험생 무료 공연 관람 할인 100%
df["할인종류명(전송처)"].unique()
# Out:
# array([None, '0', '기타', '할인정보 없음', '부산북구주민 50%', '자체할인', '전주한옥마을숙소이용객',
#        '청소년할인(24세이하)', '신용카드사', '65세이상어르신', '조기예매 40%', '50%할인', '75%할인',
#        '80%할인', '장애인(1~3급,동반1인) 20%', '장애인(4~6급,본인만) 20%', '없음',
#        '국민생활기초생활 수급자 50%', '현대일렉트릭스앤에너지시스템', '현대중공업직원 우대', '문예회원 우대',
#        '현대미포조선직원 우대', '할인없음', '현대중공업직원 가족 우대', '복지회관직원 우대', '현대중공업 임원 우대',
#        '조기예매 50%', '2.0.1.9. 이벤트', '예매시 할인', '예매시 할인 19000원',
#        '조기예매할인 40%', '2.0.1.9 중 주민번호 3자리 이상 있을 시 55%', '특별할인권소지자 60%',
#        '기간특가할인', '현대로보틱스', '현대중공업협력사직원 우대', '전북은행카드할인', '장애우(1~3급)',
#        '임직원할인', '다자녀 사랑카드 소지 가구원 20%', '가족패키지(3인이상)', '문화가 있는 날 50%',
#        '예매시 할인 11000원', '경주시민할인', '[어린이공연 국악동요극] 조기 예매 할인',
#        '24세 이하 청소년 및 대학생', '예술인패스 소지자', '장애인 및 동반 1인', '문화누리카드 소지자',
#        '병역이행명문자 및 동반 1인', '국가유공자 및 동반 1인', '경로우대자(만 65세 이상) 및 동반 1인',
#        '전라북도도민', '예매시 40%', '2.0.1.9 중 주민번호 3자리 이상 있을 시',
#        '울산광역시장 발급 자원봉사증 소지자 20%',
#        '장애인복지법 등록 장애인 50% ※ 장애인등록증 소지자 (1~3급은 동반 1명 포함 / 4~6급은 본인만)',
#        '복지할인', '예매시 할인 13000원', '만 65세 이상 50%', '[창극<지리산>] 조기 예매 할인',
#        '24세 이하 청소년 또는 대학생', '경로(55년 이전출생) 및 동반 1인', '예술인패스카드 소지자',
#        '병역이행명문가 및 동반 1인', '다둥이 행복카드 소지자', '예매시', '6인이상단체할인',
#        '현대건설기계 임원 우대', '현대건설기계(주)', '현대이엔티 직원 우대', '아이챌린지 회원 할인', '단체티켓',
#        '현대중공업어린이집 직원', '한국조선해양', '국가유공자와 그 유족 50%', '현대학원직원 우대',
#        '현대중공업터보기계직원 우대', '현대중공업MOS직원 우대',
#        '조기예매할인 (8.12.(월)부터~8.31.(토)까지)', '문화가 있는 날', '재관람 할인',
#        '현대일렉트릭 임원 우대', '조기예매', '특별할인권소지자', '예매시 17600원',
#        '예술인패스소지자 20000원', '조기예매할인', '엘사이벤트', '예매시 할인 10000원',
#        '네이버 지식쇼핑(3천원)', '문화바우처카드', 'MOU할인', '네이버 지식쇼핑(5천원)',
#        '한국조선해양 임원 우대', '네이버 지식쇼핑 V2(1천원)', '4인 패키지 할인', '조기예매할인 45%',
#        '특별할인권 소지자', '현대글로벌서비스(주)',
#        '울산혁신도시 공공기관이전에 따른 전입 임직원과 주민등록상 가족 20%', '쿠폰 할인', '울산과학대학교직원 우대',
#        '공제회 회원 2인 패키지', '아빠만원 추가관람 50%', '아빠 만원 20000원', '타임세일 60%',
#        '3인패키지', '[BC카드] 10월2주', '학생할인(초,중,고,대학생)', '참가 아티스트 예매',
#        '경주시민할인 15000원', '명예사원', '현대로보틱스 임원 우대', '엘사이벤트 55%', '사전예매',
#        '70%할인', '미포조선협력사 직원', '수험생 50% 할인', '부산시민할인 20%', '부산매직_웰컴피즘 50%',
#        '가족데이트(3인이상) 30%', '부산매직50% 50%', '출연진 할인', '문화패스 30%',
#        '부산매직_교보 30%', '초대권 100%', '아동센터 단체 45000원', '50%할인 50%',
#        '아동센터 단체 50000원', '오프라인 50%', '부산매직 30% 30%', '재관람할인 30%',
#        '(주말)경로할인(만60세이상) 40%', '저소득층,문화누리카드 소지자 50%', '특별할인',
#        '장애인(1~3급,동반1인) 50%', '(평일)경로할인(만60세이상) 50%', '직장인할인 30%',
#        '할인권종2 40000원', '1차조기예매할인', '학생할인(초,중,고/본인)', '2차조기예매할인 15%',
#        '2차조기예매할인', '3차조기예매할인 10%', '가족데이트(3인이상)', '(주말) 경로할인(만60세이상)',
#        '1달이내 에어부산or아시아나 항공권 소지자', '2020학년도 대학수학능력시험 수험증 소지자',
#        '(주말)조기예매할인', '5.18민주유공자와 그 유족 50%', '(평일)조기예매할인', '(평일)특별할인',
#        '55%할인', '일찍사서 할인', '회관 유료회원 할인', 'THEKNANTA@@교직원나라 할인', '예매 할인',
#        '크리스마스할인', '예매할인 40%', '예매할인 50%', '네이버', '티몬', '초대권', '예매할인 20%',
#        '예매할인 30%', '평일할인', '사전예매1인', '나랏말싸게 할인', '예매 할인 15%', '예매할인 45%',
#        '인터파크', '20인이상단체할인', '오픈기념특별할인', '신한카드할인 40%',
#        'BUSAN_COMPANY@@기업임직원특별할인', '블랙프라이데이', '1차조기예매할인 20%', '공무원',
#        '예매할인 35%', '장애인및국가유공자(동반1인) 50%', '차액', '크리스마스이브', '크리스마스특가1인',
#        '직장인할인 10%', '3인패키지 50%', '(크리스마스)예매시', '예매시 19000원', '회원할인',
#        '크리스마스 특가', '예매시 7000원', '티몬 조기예매', '(주말)특별할인', '크리스마스특가',
#        '허각 <공연각> 대전/대구/부산 30% 할인', '단체(10인이상)', '보호자 할인', '미취학아동', '정가',
#        '학생', '키자니아 회원 할인', '홈플러스 문화센터 회원 할인', '다자녀 가구', '인증샷 할인',
#        '프로모션(40%)', '교향악단회원', 'VIP회원', '시니어 할인', '스페셜회원', '장애인(4~6급)',
#        '음악대학 재학생', '직원할인', '국가유공자·독립유공자', '기타 할인', '에어부산/아시아나 항공권 소지자',
#        '임산부 산모카드', '학생개인할인', '가족할인(3인이상 가족)', '20-21 시즌 패키지', '국가/독립유공자',
#        '학생할인', '장애인할인', '다자녀카드할인', '등록장애인', '단원1', '장애인(1~3급)', '임산부',
#        '초/중/고/대/대학원생', '타임세일', '무용단회원', '장애인', '단체(15인이상)', '문화누리카드',
#        '극단회원', '문화예술인패스', '본공연(6/19) 관람', '20명 이상 단체할인 20%', '문화가있는날',
#        '아동동반 보호자', '커플할인', '프로모션', '예술인패스', '20인 이상 단체 20% (전화예매)',
#        '프로모션(50%)', '조기예매할인 30%', '학생할인 50%', '문화예술인패스/문화누리카드',
#        '다둥이 행복카드', '부산아쿠아리움 연간회원', '단체(30인 이상)', '합창단회원', '연극마니아',
#        '국악관현악단회원', '군인,경찰,소방공무원 할인(본인만)', '예술인할인(본인만)', '학생할인(1인4매)',
#        '밀양시민(본인만)', '단원할인', '출연진', 'SNS 좋아요 할인', '코로나극복', '어린이할인', '배우할인',
#        '학생할인(초중고대학생/본인만)', '다자녀가정 할인', '독립유공자와 그 유족 50%', 'SNS할인',
#        '미취학아동할인(24개월이상~)', '외국인', '단체할인(10인이상)', '부산시민 50%', '다중할인',
#        '현대코어모션 직원 우대', 'N', '30할인', '60%할인', '본공연(제572정기연주)예매자',
#        '에어부산?아시아나 항공권 소지자', '단체(20인이상)', '1월 조기예매(유료회원-VIP)',
#        '1월 조기예매(초,중,고 교사)', '1월 조기예매(유료회원-교향악단)', '1월 조기예매(경로)',
#        '1월 조기예매(유료회원-스페셜)', '1월 조기예매(정가)', '1월 조기예매(학생)', '1월 조기예매(장애인)',
#        '1월 조기예매(예술인)', '1월 조기예매(유료회원-극단)', '초, 중, 고 교사', '경로', '1인관람권',
#        '연지동 맛집', '1월 조기예매(문화예술인패스)', '1월 조기예매(국가/독립유공자)', '21-22 시즌 패키지',
#        '1월 조기예매(시니어)', '복지할인(동반1인)', '부모님 할인', '20인 이상 단체 30% (전화예매)',
#        '2인패키지', '4인패키지', '권종할인', '상시할인', '장애인(1~3급,동반1인)', '40할인', '2만원권',
#        '가정의달 특별할인', '단체(20인 이상)', '직원초대', '장애정도가심하지않은장애인(본인만)',
#        '1층 사전예매 1인가', '보훈의달 특별할인', '보훈의달 특별할인(선착순 30매)',
#        '[6월 위메프데이] 공연티켓 할인쿠폰', '경로우대', '백신접종자할인', '(1층)사전예매시', '출연자',
#        '예매가', '청소년 (9세~24세)', '학생 단체', '협연자 및 학생단체', '가족할인(아동포함 3인이상)',
#        '장애인 경증(4~6급)', '장애인 중증(1~3급)', '공연사 할인', '후원회원', '교직원할인',
#        'BSCC 인문학+콘서트 관람자 할인', '단체(30인이상)', '스페셜할인(본인만)', '효도할인(동반3인)',
#        '국가유공자', '코로나19 예방접종 할인', '문화패스할인', '의상자(1~2급)', '문화누리할인',
#        '가족사랑할인', '2021 수능생 50% 할인', '론더풀투나잇 매니아할인', '사전예매 1인가', '사전예매시',
#        '백신접종자(코로나)', '백신 임상시험 대상자', '현대중공업파워시스템 직원 우대', '(평일)연말특별할인',
#        '판매자 할인쿠폰', '중고생(본인만)', '(주말)연말특별할인', '청소년할인(중,고등학생/본인만)',
#        '22 시즌 패키지', '단체', '가족친화인증기업', '3인이상 예매시', '복지할인 (본인만)',
#        '빛드림 페스티벌', '유족증(국가유공자, 의사자)', '3인이상예매시', '에어부산⦁아시아나 항공권 소지자',
#        '3인이상예매할인(별봉1개증정)', '복지할인(4~6급/본인)', '[2022설] 공연티켓 할인쿠폰',
#        '[2월 위메프데이] 공연티켓 할인쿠폰', 'COMMISSION_COUPON', '유관기관 할인', '용띠 할인',
#        '아카데미 회원 할인', '티켓오픈기념할인', '복지할인(본인만)', '전원경의 아트살롱(그림콘서트) 패키지',
#        '전석', '더 찬스 할인', '[5월가정의달] 깜짝 공연티켓 할인쿠폰', '직?단원', '엄마?아빠',
#        'HYMS 직원 우대', '35할인', '50할인', '3만원권', '가정의달 특별 할인', '5만원권',
#        '단체(100인 이상)', '기업체?기관 할인', '경로우대할인(65세이상,본인만)', '대관공연 발권',
#        '50%할인권', 'COUPON', '우대 (만65세이상, 장애인, 경북도민)', '유료회원할인 100%',
#        '춘천거주지역할인 30%', '학생 및 청소년 50%', '경로할인 50%', '예술단원전용 30%',
#        '장애인할인 50%', '예술인패스 할인 20%', '초대', '경로할인', '춘천거주지역할인', '유료회원할인',
#        '학생 및 청소년', '성인(만19세 이상 ~ 만65세 미만)', '소인 (36개월 이상 ~ 만19세 미만)',
#        '65세이상 30% 할인', '예주 멤버쉽 본인할인', '장애인 30% 할인', '예주 맴버쉽 동반할인',
#        '국가유공자 50%', '재관람할인', '방과후행복카드', '부산시민할인(본인)', '학생할인(초,중,고등학생)',
#        '청소년 (8세~24세)', '현대제뉴인 직원 우대', '화승', '무료 공연 할인 100%', '20% 할인권',
#        '전석무료(신나는오케스트라) 0원', '학생/청소년', '업무협약(30%)', '더퀸 4인 패키지',
#        '더퀸 3인 패키지', '사전예매 할인', '유료회원 할인 100%', '춘천 거주지역 할인 30%',
#        '학생 및 청소년 할인 50%', '장애인 50% 할인', '청소년 50% 할인', '65세이상 50%할인',
#        '[투어컬처프로] 할인쿠폰', '동구주민&동구관내 직장인 할인', '에어부산?아시아나 탑승권 소지자',
#        '병역이행명문가(동반1인까지)', '1992년생', 'BC카드', '초중고등학생(본인만)', '청소년',
#        '직?단원?출연자', 'VIP회원 할인(동반1인)', '패키지 할인권 100%', '학생(청소년)할인 40%',
#        '가족할인(2인이상) 20%', '재단 홈페이지 회원할인 10%', '재예매  할인권 30%',
#        '출연진 및 스탭할인 50%', '장애인 할인 50%', '예술인 할인 40%', '강강술래', '탑승권',
#        '영덕군민 50%할인권', '일반 단체 50인 이상 50%', '예술인 패스 할인 20%', '춘천 거주지역 할인',
#        '유료회원 할인', '학생 및 청소년 할인', '시니어', '[투어컬처위크] 비씨카드', '[투어컬처위크] 하나카드',
#        '장애인 할인', 'HD현대 직원 우대', '국가유공자 할인 50%', '출연진 및 스탭할인', '당일할인 90%',
#        '당일할인', '무료공연 할인 100%', '학생 단체 10인 이상 70%', '예술단원전용',
#        '일반 단체 10인 이상 50%', '정가,2022 부산공연콘텐츠페스타 출연진', '일반 단체 10인 이상',
#        '카카오톡 채널추가할인', '금정구민', '금정문화회관 유료정기회원',
#        '금정문화회관 기획공연 관람자 및 문화강좌 수강생', '동아대학교 학생', '4인 관람권', '무료 공연 할인',
#        '3인 관람권', '스태프할인', '선글라스&오방색 할인 20%', '워라밸 인증기업 할인 30%',
#        '프로모션 50%', '예술인관계자', '단체(10인 이상) 40%', '플티회원할인', '선글라스&오방색 할인',
#        '다자녀할인(5매까지)', '어메이징쇼', '부산시민할인', '예술인 패스 할인 50%', '초대 100%',
#        '예술인 패스 할인', '예술인 패스 할인(본인)', '예술인 패스 할인(본인) 50%',
#        '수험생 무료 공연 관람 할인 100%', '학생(청소년)할인', '수험생 무료 공연 관람 할인', '행복한 경숙씨',
#        '학생 단체 10인 이상', '[투어컬처위크] KB국민카드', '예술인 할인', '송년음악회 할인 0원',
#        '전석초대(신나는오케스트라) 0원', '3인패키지(R석_1층)', '더퀸 R석(1층) 사전예매', '(주말)조기예매',
#        '예술단 유료회원(1인2매) 40%', '모임할인(3인이상) 20%', '단체(10인 이상)',
#        '재단 홈페이지 회원할인', '모임할인(3인이상)', '평일 사전예매', '크리스마스 특가할인',
#        '크리스마스 사전예매', '현대중공업새마을금고 직원', '크리스마스 특별할인', '(평일)조기예매',
#        '가족친화인증기업 임직원 할인', '다자녀 할인'], dtype=object)

# %%
df["결제수단명(관리시스템)"].unique()
# Out:
# array(['기타', '카드', '무통장', '현금', '다중결제', '상품권'], dtype=object)

# %%
# 무료결제, "0원 결제"
df["결제수단명(전송처)"].unique()
# Out:
# array(['현금', None, '무통장 입금', '신용카드', '카카오페이(카카오머니)', '카드', '기타', '무통장',
#        '무통장입금', '신용카드 수기결제', '신용카드 간편결제', '네이버예약 카드', '실시간계좌이체',
#        '카카오페이(카드)', '휴대폰결제', '네이버예약 계좌이체', '네이버예약 포인트', '이지웰포인트',
#        'Onepay(카드)', '다중결제', '네이버페이 포인트', 'PAYCO 포인트', '2교대 복리 포인트',
#        '스마일페이(카드)', '휴대폰', 'Onepay(계좌)', '국민카드', '농협은행,포인트,OK캐쉬백', '해피머니',
#        'PAYCO', '해피머니+신용카드', '국민은행', '비씨카드', 'S머니 + 신용카드', '컬쳐캐쉬',
#        '휴대폰 간편결제', '현대카드', '신용카드,하나투어 마일리지', '신용카드,네이버 2천원 할인쿠폰',
#        '신용카드,네이버 2천원 할인쿠폰,하나투어 마일리지', '하나투어 마일리지,휴대폰', '네이버 2천원 할인쿠폰,휴대폰',
#        '네이버 2천원 할인쿠폰,무통장 입금', '네이버 2천원 할인쿠폰,무통장 입금,하나투어 마일리지', '신용카드,휴대폰',
#        '신용카드,카카오페이_5천원권_201901', '꿈꾸는모바일 포인트', '이지웰포인트+신용카드',
#        '온라인, 마일리지결제', '급여이체 현중', '외상거래처', '신용카드, 신용카드', '외환은행', '신한카드',
#        '신한은행', '하나[구 하나SK]', '롯데카드', '신용카드, 이용권', '이제너두', '농협은행', '삼성카드',
#        '시티카드', '신한카드,OK캐쉬백', '농협카드', '무료', '하나은행', '비씨카드,포인트,OK캐쉬백',
#        '비씨카드,포인트', '99', '가스공사포인트', '새마을금고',
#        '신용카드,네이버 2천원 할인쿠폰,하나투어 마일리지,L포인트', '기업은행', '제일은행',
#        '무통장 입금,하나투어 마일리지', '컬쳐캐쉬+신용카드', '무료결제', '이지웰', '마일리지결제, 급여이체 현중',
#        '현금, 신용카드', '급여이체 일렉', '외상거래처, 외상거래처', '마일리지결제', '국민카드,OK캐쉬백',
#        '기타결제', '하나투어 마일리지', '현금, 이용권', '이용권', '포인트,하나[구 하나SK],OK캐쉬백',
#        '웹계좌입금, 마일리지결제', '계좌이체', '신한은행,OK캐쉬백', '기타결제,비씨카드', '우리은행',
#        '신용카드,L포인트', '국민카드,포인트,OK캐쉬백', '기타결제,현대카드', '상품권, 환불',
#        '하나[구 하나SK],OK캐쉬백', '이용권, 이용권', '신용카드,부산매직_웰컴피즘', '가스공사포인트+ 신용카드',
#        '신용카드,부산매직50%', '신용카드,부산매직_교보', '신용카드,부산매직 30%',
#        '부산매직_웰컴피즘,계좌환불,휴대폰', '부산매직_교보,무통장 입금', '부산매직50%,무통장 입금',
#        '부산매직_웰컴피즘,무통장 입금', '부산매직 30%,무통장 입금', '신용카드,부산매직 30%,하나투어 마일리지',
#        '신용카드,부산매직_웰컴피즘,하나투어 마일리지', '부산매직50%,휴대폰', '현금, 이용권, 이용권',
#        '네이버 2천원 할인쿠폰,무통장 입금,하나투어 마일리지,L포인트',
#        '네이버 2천원 할인쿠폰,하나투어 마일리지,휴대폰,L포인트', '계좌환불,휴대폰', '현대카드,OK캐쉬백',
#        '진로체험카드 포인트', '진로체험카드+신용카드', '포인트,현대카드,OK캐쉬백', '더난타',
#        '신한카드,포인트,OK캐쉬백', '롯데카드,포인트', '신용카드, 마일리지결제', '신한카드,포인트',
#        '티켓링크 모바일 상품권', '삼성카드,포인트', '농협카드,포인트', '카드,웰빙클럽', '로켓 카드',
#        '로켓 뱅크', '로켓 밸런스', '핸드폰', '2교대 복리 포인트+신용카드', '가상계좌', '로켓 밸런스,쿠팡캐시',
#        '쿠팡캐시', '기업은행,포인트', '하나카드', '신세계한미카드', '외환카드', 'AmexLocal카드',
#        '부산은행', '핸드폰,쿠팡캐시', '쿠팡캐시,카드', '농협', '20-21 시즌 패키지', '계좌입금',
#        '부산문화(시민)회관 기획공연 관람권(유료회원)', '수협카드', 'SC은행', '농협,신한은행', 'Visa해외카드',
#        '농협카드,현금', '수협', '우체국', '차이페이', '부산시립예술단 공연 관람권(유료회원)', '포인트,현대카드',
#        'Master해외카드', '바우처카드 포인트(구 진로체험카드)', '썸패스', '카드,수기결제',
#        '간편결제 KAKAO', '간편결제 CHAI', '적립금', '간편결제 TOSS', '간편결제 SETTLE',
#        '휴대폰 결제', '간편결제 PAYCO', 'Smilepay카드', '신용카드+포인트', '현대이지웰포인트',
#        '농협,농협중앙회', '국민은행,카카오뱅크', '포인트', '급여이체', '마일리지결제, 급여이체',
#        '21-22 시즌 패키지', '수기결제', '수기결제연결', '국민카드,포인트',
#        '기타결제,농협카드,포인트,OK캐쉬백', '국민은행,부산은행', '현대이지웰포인트+신용카드', '롯데카드,현금',
#        '웰빙클럽,카드', '신용카드+쿠폰', '0원 결제', '부산시립예술단 공연 관람권(유료회원),현대카드',
#        '인터파크페이(카드)', '광주은행카드', '신용카드, 이용권, 이용권', '인터파크페이(계좌)',
#        '쿠팡캐시,로켓 카드', '롯데카드,부산문화(시민)회관 기획공연 관람권(유료회원)', '농협은행,포인트',
#        '쿠팡캐시,로켓 밸런스', '기업은행,카카오뱅크', '기업은행,부산은행', '농협,카카오뱅크',
#        '바우처카드+신용카드(구 진로체험카드)', '카드결제', '네이버페이',
#        '국민카드,부산문화(시민)회관 기획공연 관람권(유료회원)', '부산문화(시민)회관 기획공연 관람권(유료회원),우리은행',
#        '부산문화(시민)회관 기획공연 관람권(유료회원),삼성카드', '기타은행',
#        '농협카드,부산문화(시민)회관 기획공연 관람권(유료회원)', '기업은행,우리은행', '국민은행,하나은행',
#        '롯데카드,포인트,OK캐쉬백', '기타결제,포인트,현대카드,OK캐쉬백', '기타결제,신한카드,OK캐쉬백',
#        '기타결제,롯데카드', '신용카드+쿠폰+무통장입금', '포인트,하나[구 하나SK]',
#        '부산시립예술단 공연 관람권(유료회원),부산은행', '휴대폰 결제+포인트', '경남은행,농협',
#        '국민카드,부산시립예술단 공연 관람권(유료회원)', '신용카드+무통장입금', '기타결제,포인트', '쿠폰,로켓 밸런스',
#        '쿠폰,로켓 카드', '비씨카드,OK캐쉬백', '국민은행,포인트', '해피캐시', '쿠폰,쿠팡캐시,로켓 카드',
#        '카드,쿠폰', '농협,부산문화(시민)회관 기획공연 관람권(유료회원)', '22 시즌 패키지',
#        '부산문화(시민)회관 기획공연 관람권(유료회원),부산은행', '국민카드,농협카드,삼성카드,신세계한미카드,신한카드',
#        '한미카드', '국민카드,기타결제', '삼성카드,OK캐쉬백', '광주은행,기업은행', '기타결제,신한카드,포인트',
#        '기타결제,신한카드', '기타결제,농협카드', '부산문화(시민)회관 기획공연 관람권(유료회원),신한은행',
#        '국민카드,현대카드', '국민은행,기타결제,OK캐쉬백', '전원경의 아트살롱(그림콘서트) 패키지',
#        '부산문화(시민)회관 기획공연 관람권(유료회원),비씨카드', '쿠폰+휴대폰 결제', '클립통장', '기획사입금',
#        '이제너두,카드', '부산문화(시민)회관 기획공연 관람권(유료회원),현대카드', '이지웰페이',
#        '부산시립예술단 공연 관람권(유료회원),현금', 'card', 'vbank', 'free', '카카오페이',
#        '기타결제,농협은행', '부산시립예술단 공연 관람권(유료회원),비씨카드', '우리은행,카카오뱅크',
#        '국민은행,부산시립예술단 공연 관람권(유료회원)', '복지관',
#        '부산문화(시민)회관 기획공연 관람권(유료회원),하나은행', '부산문화(시민)회관 기획공연 관람권(유료회원),신한카드',
#        '꿈꾸는모바일 포인트+신용카드', '롯데카드,부산시립예술단 공연 관람권(유료회원)', '신용카드, 외상거래처',
#        '신용카드, 상품권', '2022 부산공연콘텐츠페스타 출연진,현대카드',
#        '2022 부산공연콘텐츠페스타 출연진,농협카드', '국민카드,농협카드,신한카드,현금', '광주은행',
#        '2022 부산공연콘텐츠페스타 출연진,비씨카드', '2022 부산공연콘텐츠페스타 출연진,롯데카드',
#        '2022 부산공연콘텐츠페스타 출연진,농협', '2022 부산공연콘텐츠페스타 출연진,국민카드',
#        '2022 부산공연콘텐츠페스타 출연진,신한은행', '2022 부산공연콘텐츠페스타 출연진,삼성카드', 'bank',
#        '국민은행,부산문화(시민)회관 기획공연 관람권(유료회원)', '부산문화(시민)회관 기획공연 관람권(유료회원),현금',
#        '부산시립예술단 공연 관람권(유료회원),신한카드', '부산시립예술단 공연 관람권(유료회원),삼성카드',
#        '기타결제,삼성카드', '국민카드,기타결제,포인트'], dtype=object)

# %%
contains_lst = [
    "전석무료(0)", "전석(0)", "A석(0)", "현장판매(0)", "A석 전석소외계층초청(0)", "전석무료(0), 전석무료(0)",
    "초대권 100%", "전석초대(신나는오케스트라) 0원", "송년음악회 할인 0원", "무료 공연 할인 100%", "유료회원할인 100%",
    "유료회원 할인 100%", "초대", "초대권", "직원초대", "초대 100%", "패키지 할인권 100%", "무료공연 할인 100%",
    "수험생 무료 공연 관람 할인 100%",
    "무료결제", "0원 결제"
]
temp = df[(df["좌석등급"].apply(lambda x : x in contains_lst))|(df["할인종류명(전송처)"].apply(lambda x : x in contains_lst))|(df["결제수단명(전송처)"].apply(lambda x : x in contains_lst))]
temp[["예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
# Out:
#          예매/취소금액   할인금액   장당금액                  좌석등급 할인종류명(전송처)  \
# 0              0      0      0               전석무료(0)       None
# 1              0      0      0               전석무료(0)       None
# 2              0      0      0               전석무료(0)       None
# 3              0      0      0               전석무료(0)       None
# 4              0      0      0               전석무료(0)       None
# ...          ...    ...    ...                   ...        ...
# 2853011        0      0      0               전석무료(0)       None
# 2853012        0      0      0               전석무료(0)       None
# 2853040        0      0      0               전석무료(0)       None
# 2853041        0      0      0               전석무료(0)       None
# 2854196        0  50000  50000  R석(50000), S석(40000)        초대권
#
#                         결제수단명(전송처)
# 0                               현금
# 1                               현금
# 2                               현금
# 3                               현금
# 4                               현금
# ...                            ...
# 2853011                         현금
# 2853012                         현금
# 2853040                         현금
# 2853041                         현금
# 2854196  부산문화(시민)회관 기획공연 관람권(유료회원)
#
# [389663 rows x 6 columns]

# %%
# 여기서 무료공연인데 예매/취소금액이 0이 아닌 비정상 데이터 수정
temp[temp["예매/취소금액"]!=0][["예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
# Out:
#          예매/취소금액  할인금액    장당금액     좌석등급 할인종류명(전송처) 결제수단명(전송처)
# 91095     153000     0  153000  전석무료(0)       None         카드
# 91096     153000     0  153000  전석무료(0)       None         카드
# 135946      1000     0    1000  현장판매(0)       None         현금
# 135947      1000     0    1000  현장판매(0)       None         현금
# 135948      1000     0    1000  현장판매(0)       None         카드
# ...          ...   ...     ...      ...        ...        ...
# 1910466     1000     0    1000  전석무료(0)       None        무통장
# 2086098    10000     0   10000  전석무료(0)       None         카드
# 2086099    10000     0   10000  전석무료(0)       None         카드
# 2086100    10000     0   10000  전석무료(0)       None         카드
# 2086101    10000     0   10000  전석무료(0)       None         카드
#
# [1429 rows x 6 columns]

# %%
# 예매금액과 할인금액을 뒤바꿔주기
idx = temp[temp["예매/취소금액"]!=0][["예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]].index

for i in idx:
    df.loc[i, "할인금액"] = df.loc[i, "예매/취소금액"]
    df.loc[i, "예매/취소금액"] = 0

# %%
df.iloc[idx][["예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]].head(3)
# Out:
#         예매/취소금액    할인금액    장당금액     좌석등급 할인종류명(전송처) 결제수단명(전송처)
# 91095         0  153000  153000  전석무료(0)       None         카드
# 91096         0  153000  153000  전석무료(0)       None         카드
# 135946        0    1000    1000  현장판매(0)       None         현금

# %%
# 무료여부 붙여주기
idx = temp.index
len(idx)
# Out:
# 389663

# %%
# 무료를 1로 유료를 2로
df["무료여부"] = ""

for i in idx:
    df.loc[i, "무료여부"] = 1

df = df.replace({"무료여부": {"" : 2}})

# %% [markdown]
# # 유료공연의 가격수정

# %% [markdown]
# ## Case 1.

# %%
# case 1. 예매금액 제외 0원
# 예매금액과 장당금액을 맞추어주는 작업 시행.
pay_df = df[df["무료여부"]==2][["공연코드", "예매/취소금액", "할인금액", "장당금액", "할인종류명(전송처)", "좌석등급", "결제수단명(전송처)"]]
case_one = pay_df[(pay_df["예매/취소금액"]!=0)&(pay_df["할인금액"]==0)&(pay_df["장당금액"]==0)]
case_one
# Out:
#             공연코드  예매/취소금액  할인금액  장당금액 할인종류명(전송처)       좌석등급  결제수단명(전송처)
# 580     PF361976    10000     0     0       None  전석(20000)      무통장 입금
# 581     PF361976    10000     0     0       None  전석(20000)      무통장 입금
# 582     PF361976    20000     0     0       None  전석(20000)        신용카드
# 584     PF361976    20000     0     0       None  전석(20000)        신용카드
# 585     PF361976    20000     0     0       None  전석(20000)        신용카드
# ...          ...      ...   ...   ...        ...        ...         ...
# 836429  PF389263    10000     0     0       None  전석(20000)  S머니 + 신용카드
# 836430  PF389263    10000     0     0       None  전석(20000)  S머니 + 신용카드
# 836431  PF389263    10000     0     0       None  전석(20000)  S머니 + 신용카드
# 836432  PF389263    10000     0     0       None  전석(20000)        신용카드
# 836433  PF389263    10000     0     0       None  전석(20000)        신용카드
#
# [204699 rows x 7 columns]

# %%
idx = case_one.index

for i in idx:
    df.loc[i, "장당금액"] = df.loc[i, "예매/취소금액"]

# %%
df.iloc[idx][["공연코드", "예매/취소금액", "할인금액", "장당금액"]]
# Out:
#             공연코드  예매/취소금액  할인금액   장당금액
# 580     PF361976    10000     0  10000
# 581     PF361976    10000     0  10000
# 582     PF361976    20000     0  20000
# 584     PF361976    20000     0  20000
# 585     PF361976    20000     0  20000
# ...          ...      ...   ...    ...
# 836429  PF389263    10000     0  10000
# 836430  PF389263    10000     0  10000
# 836431  PF389263    10000     0  10000
# 836432  PF389263    10000     0  10000
# 836433  PF389263    10000     0  10000
#
# [204699 rows x 4 columns]

# %% [markdown]
# ## Case 2.

# %%
# case 3. 장당금액 제외 0원
pay_df = df[df["무료여부"]==2][["공연코드", "예매/취소금액", "할인금액", "장당금액", "할인종류명(전송처)", "좌석등급", "결제수단명(전송처)"]]
case_two = pay_df[(pay_df["예매/취소금액"]==0)&(pay_df["할인금액"]==0)&(pay_df["장당금액"]!=0)]
case_two
# Out:
#              공연코드  예매/취소금액  할인금액   장당금액 할인종류명(전송처)       좌석등급 결제수단명(전송처)
# 34841    PF373734        0     0   8000       None  전석(10000)         현금
# 34925    PF373734        0     0  10000       None  전석(10000)         현금
# 34978    PF373734        0     0   7000       None  전석(10000)         현금
# 34979    PF373734        0     0   7000       None  전석(10000)         현금
# 60783    PF373013        0     0   7000       None  전석(10000)         현금
# ...           ...      ...   ...    ...        ...        ...        ...
# 2613227  PF424367        0     0   1000       None   전석(1000)         현금
# 2625410  PF423529        0     0   4000       None   전석(5000)         현금
# 2625411  PF423529        0     0   4000       None   전석(5000)         현금
# 2666084  PF425688        0     0   8000       None  전석(10000)         현금
# 2666085  PF425688        0     0   8000       None  전석(10000)         현금
#
# [842 rows x 7 columns]

# %%
# 장당금액과 예매금액을 맞추어주는 작업 시행.
idx = case_two.index

for i in idx:
    df.loc[i, "예매/취소금액"] = df.loc[i, "장당금액"]

# %% [markdown]
# ## Case 3.

# %%
# case 3. 예매금액만 0원
# 장당금액 - 할인금액 = 예매금액 맞춰주기
# 할인금액이 장당금액보다 큰 애들은 제거.
pay_df = df[df["무료여부"]==2][["공연코드", "예매/취소금액", "할인금액", "장당금액", "예매/취소구분", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
case_thr = pay_df[(pay_df["예매/취소금액"]==0)&(pay_df["할인금액"]!=0)&(pay_df["장당금액"]!=0)]
case_thr
# Out:
#              공연코드  예매/취소금액   할인금액   장당금액  예매/취소구분                  좌석등급  \
# 8595     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8596     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8597     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8598     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8599     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# ...           ...      ...    ...    ...      ...                   ...
# 2850646  PF425620        0  40000  10000        1             전석(10000)
# 2850701  PF425620        0  30000  10000        1             전석(10000)
# 2850778  PF425620        0  20000  10000        1             전석(10000)
# 2850817  PF425620        0  80000  10000        1             전석(10000)
# 2850986  PF425620        0  20000  10000        1             전석(10000)
#
#         할인종류명(전송처) 결제수단명(전송처)
# 8595            기타         기타
# 8596            기타         기타
# 8597            기타         기타
# 8598            기타         기타
# 8599            기타         기타
# ...            ...        ...
# 2850646       None         99
# 2850701       None         99
# 2850778       None         99
# 2850817       None         99
# 2850986       None         99
#
# [17251 rows x 8 columns]

# %%
# 할인금액이 장당금액보다 작은 정상적인 경우
case_thr[case_thr["할인금액"] < case_thr["장당금액"]]
# Out:
# Empty DataFrame
# Columns: [공연코드, 예매/취소금액, 할인금액, 장당금액, 예매/취소구분, 좌석등급, 할인종류명(전송처), 결제수단명(전송처)]
# Index: []

# %%
# 위의 경우가 없기 떄문에 같지 않은 애들 제거.
new_case_thr = case_thr[case_thr["할인금액"] != case_thr["장당금액"]]

# %%
idx = new_case_thr.index
df = df.drop(idx, axis=0)
df = df.reset_index(drop=True)

# %%
# 정상적인 경우는 예매금액 = 장당금액 - 할인금액으로 맞춰주기

# %%
# df 바뀌었으므로 다시 생성
pay_df = df[df["무료여부"]==2][["공연코드", "예매/취소금액", "할인금액", "장당금액", "예매/취소구분", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
case_thr = pay_df[(pay_df["예매/취소금액"]==0)&(pay_df["할인금액"]!=0)&(pay_df["장당금액"]!=0)]
case_thr
# Out:
#              공연코드  예매/취소금액   할인금액   장당금액  예매/취소구분                  좌석등급  \
# 8595     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8596     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8597     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8598     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# 8599     PF360569        0  30000  30000        1  R석(30000), S석(20000)
# ...           ...      ...    ...    ...      ...                   ...
# 2806761  PF422663        0  35000  35000        1  R석(35000), S석(30000)
# 2806782  PF422663        0  35000  35000        1  R석(35000), S석(30000)
# 2806790  PF425517        0  15000  15000        1             전석(15000)
# 2806791  PF425517        0  15000  15000        1             전석(15000)
# 2820230  PF422663        0  35000  35000        1  R석(35000), S석(30000)
#
#         할인종류명(전송처) 결제수단명(전송처)
# 8595            기타         기타
# 8596            기타         기타
# 8597            기타         기타
# 8598            기타         기타
# 8599            기타         기타
# ...            ...        ...
# 2806761         기타         현금
# 2806782         기타         현금
# 2806790       자체할인         기타
# 2806791       자체할인         기타
# 2820230         기타         현금
#
# [16526 rows x 8 columns]

# %%
idx = case_thr.index

for i in idx:
    df.loc[i, "예매/취소금액"] = df.loc[i, "장당금액"] - df.loc[i, "할인금액"]

# %% [markdown]
# ## case 4.

# %%
# 같은 공연장의 같은공연을 본 사람들의 평균 금액을 이용
df["공연시설_공연_코드"] = df["공연시설코드"] + df["공연코드"]

# %%
# case 4. 모두 0인 경우
pay_df = df[df["무료여부"]==2][["공연시설_공연_코드", "예매/취소금액", "할인금액", "장당금액"]]
pay_df[(pay_df["예매/취소금액"]==0)&(pay_df["할인금액"]==0)&(pay_df["장당금액"]==0)].head(3)
# Out:
#            공연시설_공연_코드  예매/취소금액  할인금액  장당금액
# 601  FC222397PF361976        0     0     0
# 602  FC222397PF361976        0     0     0
# 603  FC222397PF361976        0     0     0

# %%
# 3개 컬럼이 모두 누락된 애들을 위해서 공연시설_공연_코드를 이용
# 단수차이가 있기 때문에 예매/취소금액, 할인금액만 그대로 쓰고 장당금액은 두개의 합계로 계산
temp = df[df["무료여부"]==2].groupby("공연시설_공연_코드").mean().reset_index()[["공연시설_공연_코드", "예매/취소금액", "할인금액", "장당금액"]]
temp = round(temp)
temp = temp.astype({'예매/취소금액':'int64'})
temp = temp.astype({'할인금액':'int64'})
temp = temp.astype({'장당금액':'int64'})
temp.head()
# Out:
#          공연시설_공연_코드  예매/취소금액  할인금액   장당금액
# 0  FC222006PF310578     4702     0   4702
# 1  FC222006PF317488     7778     0   7778
# 2  FC222007PF301466    19209     0  19209
# 3  FC222007PF303033    24430     0  24430
# 4  FC222007PF303808    30038   852  30877

# %%
# 근데, 유료공연이고 공연을 본 모든 사람들의 평균 금액 3개가 모두 0인 데이터 제거
temp[(temp["예매/취소금액"]==0)&(temp["할인금액"]==0)&(temp["장당금액"]==0)]
# Out:
#             공연시설_공연_코드  예매/취소금액  할인금액  장당금액
# 56    FC222048PF301332        0     0     0
# 60    FC222048PF305630        0     0     0
# 61    FC222048PF306638        0     0     0
# 63    FC222048PF307315        0     0     0
# 65    FC222048PF311890        0     0     0
# ...                ...      ...   ...   ...
# 6922  FC223975PF319419        0     0     0
# 6927  FC224024PF398557        0     0     0
# 6984  FC224848PF300338        0     0     0
# 7047  FC224991PF423705        0     0     0
# 7048  FC224991PF424829        0     0     0
#
# [217 rows x 4 columns]

# %%
idx = temp[(temp["예매/취소금액"]==0)&(temp["할인금액"]==0)&(temp["장당금액"]==0)]["공연시설_공연_코드"].unique()
new_idx = []
for i in range(len(idx)):
    temp_idx = df[df.loc[:,"공연시설_공연_코드"] == idx[i]].index
    new_idx.append(temp_idx)

# %%
res = []

for i in range(len(new_idx)):
    num = len(new_idx[i])
    res.append(num)

# %%
res_idx = []

for i in range(len(new_idx)):
    for j in range(len(new_idx[i])):
        num = new_idx[i][j]
        res_idx.append(num)

# %%
df = df.drop(res_idx, axis=0)
df = df.reset_index(drop=True)

# %%
# 데이터가 바뀌었으므로 temp다시 생성
temp = df[df["무료여부"]==2].groupby("공연시설_공연_코드").mean().reset_index()[["공연시설_공연_코드", "예매/취소금액", "할인금액", "장당금액"]]
temp = round(temp)
temp = temp.astype({'예매/취소금액':'int64'})
temp = temp.astype({'할인금액':'int64'})
temp = temp.astype({'장당금액':'int64'})
temp.head()
# Out:
#          공연시설_공연_코드  예매/취소금액  할인금액   장당금액
# 0  FC222006PF310578     4702     0   4702
# 1  FC222006PF317488     7778     0   7778
# 2  FC222007PF301466    19209     0  19209
# 3  FC222007PF303033    24430     0  24430
# 4  FC222007PF303808    30038   852  30877

# %%
temp[(temp["예매/취소금액"]==0)&(temp["할인금액"]==0)&(temp["장당금액"]==0)]
# Out:
# Empty DataFrame
# Columns: [공연시설_공연_코드, 예매/취소금액, 할인금액, 장당금액]
# Index: []

# %%
pay_df = df[df["무료여부"]==2][["공연시설_공연_코드", "예매/취소금액", "할인금액", "장당금액", "예매/취소구분"]]
case_four = pay_df[(pay_df["예매/취소금액"]==0)&(pay_df["할인금액"]==0)&(pay_df["장당금액"]==0)]
case_four.head()
# Out:
#            공연시설_공연_코드  예매/취소금액  할인금액  장당금액  예매/취소구분
# 601  FC222397PF361976        0     0     0        1
# 602  FC222397PF361976        0     0     0        1
# 603  FC222397PF361976        0     0     0        1
# 604  FC222397PF361976        0     0     0        1
# 605  FC222397PF361976        0     0     0        1

# %%
# 평균값을 df에 반영하여 수정
idx = case_four["공연시설_공연_코드"].index
len(idx)
# Out:
# 328317

# %%
code = case_four["공연시설_공연_코드"].unique()
len(code)
# Out:
# 2333

# %%
case_four_temp = temp[temp["공연시설_공연_코드"].apply(lambda x : x in code)]

# %%
def MakePrice(df, idx, temp):
    for i in idx:
        code = df.iloc[i]["공연시설_공연_코드"]
        df.loc[i, "예매/취소금액"] = temp[temp["공연시설_공연_코드"]==code]["예매/취소금액"].values[0]
        df.loc[i, "할인금액"] = temp[temp["공연시설_공연_코드"]==code]["할인금액"].values[0]
        df.loc[i, "장당금액"] = df.loc[i, "예매/취소금액"] + df.loc[i, "할인금액"]
    return df

# %%
df = MakePrice(df, idx, case_four_temp)

# %%
df.iloc[idx][["공연시설_공연_코드", "예매/취소금액", "할인금액", "장당금액", "예매/취소구분"]]
# Out:
#                공연시설_공연_코드  예매/취소금액  할인금액   장당금액  예매/취소구분
# 601      FC222397PF361976     7528     0   7528        1
# 602      FC222397PF361976     7528     0   7528        1
# 603      FC222397PF361976     7528     0   7528        1
# 604      FC222397PF361976     7528     0   7528        1
# 605      FC222397PF361976     7528     0   7528        1
# ...                   ...      ...   ...    ...      ...
# 2785630  FC222759PF426633    15642     0  15642        1
# 2785631  FC222759PF426633    15642     0  15642        1
# 2785638  FC222759PF426633    15642     0  15642        1
# 2785641  FC222759PF426633    15642     0  15642        1
# 2785642  FC222759PF426633    15642     0  15642        1
#
# [328317 rows x 5 columns]

# %% [markdown]
# # 이상치 처리

# %%
df.describe()
# Out:
#                 좌석수    예매/취소구분       예매/취소금액     예매/취소방식코드        결제수단코드  \
# count  2.786276e+06  2786276.0  2.786276e+06  2.786276e+06  2.786276e+06
# mean   6.582555e+02        1.0  1.629438e+04  2.970634e+01  2.670760e+01
# std    2.064196e+02        0.0  3.921952e+04  4.379182e+01  4.230045e+01
# min    3.000000e+02        1.0  0.000000e+00  1.000000e+00  1.000000e+00
# 25%    4.780000e+02        1.0  5.000000e+03  2.000000e+00  2.000000e+00
# 50%    6.860000e+02        1.0  1.050000e+04  2.000000e+00  2.000000e+00
# 75%    8.240000e+02        1.0  2.100000e+04  9.900000e+01  9.900000e+01
# max    9.990000e+02        1.0  5.260000e+07  9.900000e+01  9.900000e+01
#
#                할인금액        할인종류코드          장당금액          년도_월        년도_월_일  \
# count  2.786276e+06  2.786276e+06  2.786276e+06  2.786276e+06  2.786276e+06
# mean   8.720989e+02  9.326983e+01  1.697630e+04  2.021040e+05  2.021042e+07
# std    4.817126e+03  2.274344e+01  3.764735e+04  1.201727e+02  1.201717e+04
# min    0.000000e+00  1.000000e+00  0.000000e+00  2.019070e+05  2.019070e+07
# 25%    0.000000e+00  9.900000e+01  5.000000e+03  2.020060e+05  2.020063e+07
# 50%    0.000000e+00  9.900000e+01  1.200000e+04  2.021120e+05  2.021122e+07
# 75%    0.000000e+00  9.900000e+01  2.270300e+04  2.022080e+05  2.022082e+07
# max    7.000000e+05  9.900000e+01  5.260000e+07  2.022120e+05  2.022123e+07
#
#                  년도             월             일       예매건수       취소건수  \
# count  2.786276e+06  2.786276e+06  2.786276e+06  2786276.0  2786276.0
# mean   2.020955e+03  8.525250e+00  1.683404e+01        1.0        0.0
# std    1.208046e+00  2.954547e+00  8.716693e+00        0.0        0.0
# min    2.019000e+03  1.000000e+00  1.000000e+00        1.0        0.0
# 25%    2.020000e+03  7.000000e+00  9.000000e+00        1.0        0.0
# 50%    2.021000e+03  9.000000e+00  1.700000e+01        1.0        0.0
# 75%    2.022000e+03  1.100000e+01  2.400000e+01        1.0        0.0
# max    2.022000e+03  1.200000e+01  3.100000e+01        1.0        0.0
#
#                무료여부
# count  2.786276e+06
# mean   1.860761e+00
# std    3.461953e-01
# min    1.000000e+00
# 25%    2.000000e+00
# 50%    2.000000e+00
# 75%    2.000000e+00
# max    2.000000e+00

# %% [markdown]
# ## 예매/취소금액

# %%
# 예매/취소금액
5.260000e+07
# Out:
# 52600000.0

# %%
# 예매/취소금액이 5260만원인 경우 -> 정상으로 봄.
# 좌석수가 962석이고 결제수단명이 외상거래처(기업) 이므로. 통대관한 경우로 보임.
# 시기도 코로나 이후로 적절함.
df[df["예매/취소금액"]==52600000][["전송사업자명", "주소", "좌석수", "공연일시", "예매/취소일시", "입장권고유번호", "예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
# Out:
#         전송사업자명                      주소  좌석수                공연일시  \
# 2373637  현대예술관  울산광역시 동구 명덕로 10 (서부동)   962 2022-10-26 10:00:00
#
#                     예매/취소일시                 입장권고유번호   예매/취소금액  할인금액      장당금액  \
# 2373637 2022-10-25 17:31:00  2022102501020202001010  52600000     0  52600000
#
#                            좌석등급 할인종류명(전송처) 결제수단명(전송처)
# 2373637  1층석(35000), 2층석(25000)       할인없음      외상거래처

# %%
df[df["예매/취소금액"]>200000][["전송사업자명", "좌석수", "공연일시", "예매/취소일시", "입장권고유번호", "예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]].sort_values("장당금액")
# Out:
#           전송사업자명  좌석수                공연일시             예매/취소일시  \
# 2286851  국립부산국악원  686 2022-10-07 19:30:00 2022-10-05 13:39:00
# 2164766  국립부산국악원  686 2022-09-04 17:00:00 2022-08-17 13:53:00
# 1716477  국립부산국악원  686 2022-05-21 15:00:00 2022-05-21 09:29:00
# 2294001  국립부산국악원  686 2022-10-08 15:00:00 2022-10-05 13:52:00
# 702155   국립부산국악원  686 2020-07-10 19:30:00 2020-07-10 19:18:00
# ...          ...  ...                 ...                 ...
# 535472   국립부산국악원  686 2019-12-20 19:30:00 2019-11-28 14:37:00
# 1367767     티켓링크  455 2021-12-10 19:30:00 2021-12-10 14:09:00
# 102769      예스24  978 2019-08-16 15:00:00 2019-07-10 09:06:00
# 102768      예스24  978 2019-08-16 15:00:00 2019-07-10 09:06:00
# 2373637    현대예술관  962 2022-10-26 10:00:00 2022-10-25 17:31:00
#
#                         입장권고유번호   예매/취소금액    할인금액      장당금액  \
# 2286851         20221005-133909    348800  523200      8000
# 2164766         20220817-135302    240000  240000      8000
# 1716477         20220521-092918    280000  280000      8000
# 2294001         20221005-135228    350400  525600      8000
# 702155          20200710-191813    221600   90400      8000
# ...                         ...       ...     ...       ...
# 535472          20191128-143737   4720000       0   4720000
# 1367767            1426356353_1   6600000       0   6600000
# 102769          721126122800091  10000000       0  10000000
# 102768          721126122800090  10000000       0  10000000
# 2373637  2022102501020202001010  52600000       0  52600000
#
#                            좌석등급        할인종류명(전송처) 결제수단명(전송처)
# 2286851     S석(10000), A석(8000)          직?단원?출연자         99
# 2164766     S석(10000), A석(8000)                경로         99
# 1716477     S석(10000), A석(8000)         기업체?기관 할인         99
# 2294001     S석(10000), A석(8000)          직?단원?출연자         99
# 702155      S석(10000), A석(8000)  24세 이하 청소년 및 대학생         99
# ...                         ...               ...        ...
# 535472                전석(20000)              None         99
# 1367767               전석(30000)              None  신용카드 수기결제
# 102769   양일권(49500), 일일권(27500)                기타         현금
# 102768   양일권(49500), 일일권(27500)                기타         현금
# 2373637  1층석(35000), 2층석(25000)              할인없음      외상거래처
#
# [357 rows x 11 columns]

# %%
temp = df[df["예매/취소금액"]>200000][["전송사업자명", "좌석수", "공연일시", "예매/취소일시", "입장권고유번호", "예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
temp = temp[(temp["결제수단명(전송처)"]=="현금")|(temp["결제수단명(전송처)"]=="99")|(temp["할인종류명(전송처)"]=="기타")|(temp["할인종류명(전송처)"]==None)]
temp
# Out:
#           전송사업자명  좌석수                공연일시             예매/취소일시  \
# 102768      예스24  978 2019-08-16 15:00:00 2019-07-10 09:06:00
# 102769      예스24  978 2019-08-16 15:00:00 2019-07-10 09:06:00
# 277505   국립부산국악원  686 2019-10-12 17:00:00 2019-09-26 14:40:00
# 277807   국립부산국악원  686 2019-10-12 17:00:00 2019-10-08 13:36:00
# 525758   국립부산국악원  686 2019-12-18 19:30:00 2019-12-04 13:46:00
# 526434   국립부산국악원  686 2019-12-18 19:30:00 2019-12-17 10:01:00
# 526435   국립부산국악원  686 2019-12-18 19:30:00 2019-12-17 10:02:00
# 535472   국립부산국악원  686 2019-12-20 19:30:00 2019-11-28 14:37:00
# 538281   국립부산국악원  686 2019-12-20 19:30:00 2019-12-17 13:52:00
# 553025   국립부산국악원  686 2019-12-21 18:00:00 2019-12-18 13:57:00
# 553026   국립부산국악원  686 2019-12-21 18:00:00 2019-12-18 13:58:00
# 553027   국립부산국악원  686 2019-12-21 18:00:00 2019-12-18 13:59:00
# 702155   국립부산국악원  686 2020-07-10 19:30:00 2020-07-10 19:18:00
# 812615   국립부산국악원  686 2020-11-22 15:00:00 2020-11-22 10:22:00
# 1030126  국립부산국악원  686 2021-07-14 19:30:00 2021-07-02 16:36:00
# 1072289  국립부산국악원  686 2021-08-07 17:00:00 2021-07-31 18:25:00
# 1680821   네이버N예약  994 2022-05-13 19:30:00 2022-04-24 18:45:00
# 1680839   네이버N예약  994 2022-05-13 19:30:00 2022-04-25 13:46:00
# 1680843   네이버N예약  994 2022-05-13 19:30:00 2022-04-25 22:57:00
# 1680964   네이버N예약  994 2022-05-13 19:30:00 2022-04-29 20:28:00
# 1680975   네이버N예약  994 2022-05-13 19:30:00 2022-05-01 00:04:00
# 1680985   네이버N예약  994 2022-05-13 19:30:00 2022-05-01 20:00:00
# 1681012   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 09:07:00
# 1681032   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 17:05:00
# 1681033   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 17:05:00
# 1681034   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 17:05:00
# 1681076     인터파크  994 2022-05-13 19:30:00 2022-05-04 12:04:00
# 1681077   네이버N예약  994 2022-05-13 19:30:00 2022-05-04 12:11:00
# 1681133   네이버N예약  994 2022-05-13 19:30:00 2022-05-04 23:21:00
# 1681194   네이버N예약  994 2022-05-13 19:30:00 2022-05-07 21:19:00
# 1681594   네이버N예약  994 2022-05-13 19:30:00 2022-05-12 18:51:00
# 1692956   네이버N예약  994 2022-05-14 18:00:00 2022-04-22 21:54:00
# 1692961   네이버N예약  994 2022-05-14 18:00:00 2022-04-24 00:19:00
# 1692968   네이버N예약  994 2022-05-14 18:00:00 2022-04-25 09:37:00
# 1692972   네이버N예약  994 2022-05-14 18:00:00 2022-04-25 12:32:00
# 1692973   네이버N예약  994 2022-05-14 18:00:00 2022-04-25 12:32:00
# 1692987   네이버N예약  994 2022-05-14 18:00:00 2022-04-27 15:51:00
# 1692988   네이버N예약  994 2022-05-14 18:00:00 2022-04-27 21:06:00
# 1692989   네이버N예약  994 2022-05-14 18:00:00 2022-04-28 09:27:00
# 1693006   네이버N예약  994 2022-05-14 18:00:00 2022-05-03 20:49:00
# 1693007   네이버N예약  994 2022-05-14 18:00:00 2022-05-03 21:24:00
# 1693010   네이버N예약  994 2022-05-14 18:00:00 2022-05-03 22:26:00
# 1693045   네이버N예약  994 2022-05-14 18:00:00 2022-05-07 21:02:00
# 1693046   네이버N예약  994 2022-05-14 18:00:00 2022-05-08 17:48:00
# 1693079   네이버N예약  994 2022-05-14 18:00:00 2022-05-13 15:10:00
# 1716477  국립부산국악원  686 2022-05-21 15:00:00 2022-05-21 09:29:00
# 1867605  국립부산국악원  686 2022-06-29 19:30:00 2022-06-22 10:40:00
# 1870785  국립부산국악원  686 2022-06-30 19:30:00 2022-06-22 11:01:00
# 1976422  국립부산국악원  686 2022-07-23 17:00:00 2022-07-14 15:45:00
# 2063364  국립부산국악원  686 2022-08-13 17:00:00 2022-07-14 09:29:00
# 2065650  국립부산국악원  686 2022-08-13 17:00:00 2022-08-13 16:18:00
# 2164766  국립부산국악원  686 2022-09-04 17:00:00 2022-08-17 13:53:00
# 2286851  국립부산국악원  686 2022-10-07 19:30:00 2022-10-05 13:39:00
# 2294001  국립부산국악원  686 2022-10-08 15:00:00 2022-10-05 13:52:00
#
#                  입장권고유번호   예매/취소금액    할인금액      장당금액  \
# 102768   721126122800090  10000000       0  10000000
# 102769   721126122800091  10000000       0  10000000
# 277505   20190926-144012    350000  350000     10000
# 277807   20191008-133632    300000  300000     10000
# 525758   20191204-134633  17200000       0     70000
# 526434   20191217-100139   2240000       0     70000
# 526435   20191217-100229   3200000       0     70000
# 535472   20191128-143737   4720000       0   4720000
# 538281   20191217-135241   1573333   66667   1640000
# 553025   20191218-135731   2170000       0     10000
# 553026   20191218-135831   5480000       0     10000
# 553027   20191218-135900   2170000       0     10000
# 702155   20200710-191813    221600   90400      8000
# 812615   20201122-102256    240000  240000     10000
# 1030126  20210702-163605    931000  399000     10000
# 1072289  20210731-182509    220000  220000     10000
# 1680821      264227887_0    286000       0    286000
# 1680839      264495850_0    286000       0    286000
# 1680843      264722870_0    286000       0    286000
# 1680964      266577686_0    286000       0    286000
# 1680975      267096938_0    286000       0    286000
# 1680985      267429381_0    286000       0    286000
# 1681012      268104323_0    286000       0    286000
# 1681032      268347554_0    286000       0    286000
# 1681033      268347554_1    286000       0    286000
# 1681034      268347554_2    286000       0    286000
# 1681076      T1931586370    242000       0    242000
# 1681077      268676687_0    286000       0    286000
# 1681133      268997936_0    242000       0    242000
# 1681194      270376861_0    242000       0    242000
# 1681594      272626960_0    286000       0    286000
# 1692956      263542234_0    286000       0    286000
# 1692961      263973039_0    286000       0    286000
# 1692968      264372929_0    286000       0    286000
# 1692972      264457569_0    286000       0    286000
# 1692973      264457569_1    286000       0    286000
# 1692987      265487454_0    286000       0    286000
# 1692988      265643855_0    286000       0    286000
# 1692989      265782153_0    286000       0    286000
# 1693006      268443187_2    242000       0    242000
# 1693007      268456821_0    286000       0    286000
# 1693010      268481354_0    242000       0    242000
# 1693045      270372228_0    286000       0    286000
# 1693046      270645778_0    286000       0    286000
# 1693079      273040150_0    286000       0    286000
# 1716477  20220521-092918    280000  280000      8000
# 1867605  20220622-104008   2360000       0     10000
# 1870785  20220622-110158   2360000       0     10000
# 1976422  20220714-154559    700000  700000     10000
# 2063364  20220714-092944    400000  400000     10000
# 2065650  20220813-161823    220000  220000     10000
# 2164766  20220817-135302    240000  240000      8000
# 2286851  20221005-133909    348800  523200      8000
# 2294001  20221005-135228    350400  525600      8000
#
#                                      좌석등급                      할인종류명(전송처)  \
# 102768             양일권(49500), 일일권(27500)                              기타
# 102769             양일권(49500), 일일권(27500)                              기타
# 277505               R석(20000), S석(10000)  조기예매할인 (8.12.(월)부터~8.31.(토)까지)
# 277807               R석(20000), S석(10000)  조기예매할인 (8.12.(월)부터~8.31.(토)까지)
# 525758   S석(100000), A석(70000), B석(30000)                            None
# 526434   S석(100000), A석(70000), B석(30000)                            None
# 526435   S석(100000), A석(70000), B석(30000)                            None
# 535472                          전석(20000)                            None
# 538281                          전석(20000)                            None
# 553025               S석(30000), A석(10000)                            None
# 553026               S석(30000), A석(10000)                            None
# 553027               S석(30000), A석(10000)                            None
# 702155                S석(10000), A석(8000)                24세 이하 청소년 및 대학생
# 812615               S석(20000), A석(10000)                        부산시민 50%
# 1030126              S석(20000), A석(10000)            20인 이상 단체 30% (전화예매)
# 1072289              S석(20000), A석(10000)                             출연자
# 1680821            R석(143000), S석(121000)                              기타
# 1680839            R석(143000), S석(121000)                              기타
# 1680843            R석(143000), S석(121000)                              기타
# 1680964            R석(143000), S석(121000)                              기타
# 1680975            R석(143000), S석(121000)                              기타
# 1680985            R석(143000), S석(121000)                              기타
# 1681012            R석(143000), S석(121000)                              기타
# 1681032            R석(143000), S석(121000)                              기타
# 1681033            R석(143000), S석(121000)                              기타
# 1681034            R석(143000), S석(121000)                              기타
# 1681076            R석(143000), S석(121000)                            None
# 1681077            R석(143000), S석(121000)                              기타
# 1681133            R석(143000), S석(121000)                              기타
# 1681194            R석(143000), S석(121000)                              기타
# 1681594            R석(143000), S석(121000)                              기타
# 1692956            R석(143000), S석(121000)                              기타
# 1692961            R석(143000), S석(121000)                              기타
# 1692968            R석(143000), S석(121000)                              기타
# 1692972            R석(143000), S석(121000)                              기타
# 1692973            R석(143000), S석(121000)                              기타
# 1692987            R석(143000), S석(121000)                              기타
# 1692988            R석(143000), S석(121000)                              기타
# 1692989            R석(143000), S석(121000)                              기타
# 1693006            R석(143000), S석(121000)                              기타
# 1693007            R석(143000), S석(121000)                              기타
# 1693010            R석(143000), S석(121000)                              기타
# 1693045            R석(143000), S석(121000)                              기타
# 1693046            R석(143000), S석(121000)                              기타
# 1693079            R석(143000), S석(121000)                              기타
# 1716477               S석(10000), A석(8000)                       기업체?기관 할인
# 1867605                              None                            None
# 1870785                              None                            None
# 1976422              S석(20000), A석(10000)                             출연자
# 2063364              S석(20000), A석(10000)                             출연자
# 2065650              S석(20000), A석(10000)                             출연자
# 2164766               S석(10000), A석(8000)                              경로
# 2286851               S석(10000), A석(8000)                        직?단원?출연자
# 2294001               S석(10000), A석(8000)                        직?단원?출연자
#
#         결제수단명(전송처)
# 102768          현금
# 102769          현금
# 277505          99
# 277807          99
# 525758          99
# 526434          99
# 526435          99
# 535472          99
# 538281          99
# 553025          99
# 553026          99
# 553027          99
# 702155          99
# 812615          99
# 1030126         99
# 1072289         99
# 1680821         카드
# 1680839         카드
# 1680843         카드
# 1680964         카드
# 1680975         카드
# 1680985         카드
# 1681012         카드
# 1681032        무통장
# 1681033        무통장
# 1681034        무통장
# 1681076         현금
# 1681077         카드
# 1681133         카드
# 1681194         카드
# 1681594         기타
# 1692956         카드
# 1692961         카드
# 1692968         카드
# 1692972         카드
# 1692973         카드
# 1692987         카드
# 1692988         카드
# 1692989         기타
# 1693006         카드
# 1693007         카드
# 1693010        무통장
# 1693045         카드
# 1693046         카드
# 1693079         카드
# 1716477         99
# 1867605         99
# 1870785         99
# 1976422         99
# 2063364         99
# 2065650         99
# 2164766         99
# 2286851         99
# 2294001         99

# %%
# 할인종류와 결제수단이 이상한 애들만 제거 - 명확하지 않은거
idx = [102755,  102756,  523219,  523895,  523896,  532933,  535742, 550482,  550483,  550484, 1864641, 1867821]
df = df.drop(idx, axis=0)
df = df.reset_index(drop=True)

# %% [markdown]
# ## 할인금액

# %%
# 할인
7.000000e+05
# Out:
# 700000.0

# %%
# 할인금액 700000만원 문제 없어보임.
df[df["할인금액"]==700000][["좌석수", "공연일시", "예매/취소일시", "입장권고유번호", "예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
# Out:
#          좌석수                공연일시             예매/취소일시          입장권고유번호  \
# 1976410  686 2022-07-23 17:00:00 2022-07-14 15:45:00  20220714-154559
#
#          예매/취소금액    할인금액   장당금액                  좌석등급 할인종류명(전송처) 결제수단명(전송처)
# 1976410   700000  700000  10000  S석(20000), A석(10000)        출연자         99

# %%
# 그 외 문제없어 보임.
df[df["할인금액"]>=200000][["좌석수", "공연일시", "예매/취소일시", "입장권고유번호", "예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
# Out:
#          좌석수                공연일시             예매/취소일시          입장권고유번호  \
# 130446   686 2019-08-24 17:00:00 2019-07-23 14:14:00  20190723-141437
# 277503   686 2019-10-12 17:00:00 2019-09-26 14:40:00  20190926-144012
# 277805   686 2019-10-12 17:00:00 2019-10-08 13:36:00  20191008-133632
# 535465   686 2019-12-20 19:30:00 2019-11-28 14:34:00  20191128-143453
# 812605   686 2020-11-22 15:00:00 2020-11-22 10:22:00  20201122-102256
# 1030116  686 2021-07-14 19:30:00 2021-07-02 16:36:00  20210702-163605
# 1072275  686 2021-08-07 17:00:00 2021-07-27 10:53:00  20210727-105315
# 1072279  686 2021-08-07 17:00:00 2021-07-31 18:25:00  20210731-182509
# 1713470  686 2022-05-20 19:30:00 2022-05-20 10:30:00  20220520-103007
# 1716467  686 2022-05-21 15:00:00 2022-05-21 09:29:00  20220521-092918
# 1930676  686 2022-07-13 19:30:00 2022-07-12 15:28:00  20220712-152835
# 1976410  686 2022-07-23 17:00:00 2022-07-14 15:45:00  20220714-154559
# 2063352  686 2022-08-13 17:00:00 2022-07-14 09:29:00  20220714-092944
# 2065638  686 2022-08-13 17:00:00 2022-08-13 16:18:00  20220813-161823
# 2164754  686 2022-09-04 17:00:00 2022-08-17 13:53:00  20220817-135302
# 2164982  686 2022-09-04 17:00:00 2022-08-30 17:15:00  20220830-171525
# 2286839  686 2022-10-07 19:30:00 2022-10-05 13:39:00  20221005-133909
# 2293989  686 2022-10-08 15:00:00 2022-10-05 13:52:00  20221005-135228
#
#          예매/취소금액    할인금액   장당금액                  좌석등급  \
# 130446    200000  200000   8000   S석(10000), A석(8000)
# 277503    350000  350000  10000  R석(20000), S석(10000)
# 277805    300000  300000  10000  R석(20000), S석(10000)
# 535465         0  200000      0             전석(20000)
# 812605    240000  240000  10000  S석(20000), A석(10000)
# 1030116   931000  399000  10000  S석(20000), A석(10000)
# 1072275   200000  200000  10000  S석(20000), A석(10000)
# 1072279   220000  220000  10000  S석(20000), A석(10000)
# 1713470   200000  200000   8000   S석(10000), A석(8000)
# 1716467   280000  280000   8000   S석(10000), A석(8000)
# 1930676   200000  200000  10000  S석(20000), A석(10000)
# 1976410   700000  700000  10000  S석(20000), A석(10000)
# 2063352   400000  400000  10000  S석(20000), A석(10000)
# 2065638   220000  220000  10000  S석(20000), A석(10000)
# 2164754   240000  240000   8000   S석(10000), A석(8000)
# 2164982   200000  200000   8000   S석(10000), A석(8000)
# 2286839   348800  523200   8000   S석(10000), A석(8000)
# 2293989   350400  525600   8000   S석(10000), A석(8000)
#
#                              할인종류명(전송처) 결제수단명(전송처)
# 130446               [창극<지리산>] 조기 예매 할인         99
# 277503   조기예매할인 (8.12.(월)부터~8.31.(토)까지)         99
# 277805   조기예매할인 (8.12.(월)부터~8.31.(토)까지)         99
# 535465                             None         99
# 812605                         부산시민 50%         99
# 1030116            20인 이상 단체 30% (전화예매)         99
# 1072275                             출연자         99
# 1072279                             출연자         99
# 1713470                       기업체?기관 할인         99
# 1716467                       기업체?기관 할인         99
# 1930676                             출연자         99
# 1976410                             출연자         99
# 2063352                             출연자         99
# 2065638                             출연자         99
# 2164754                              경로         99
# 2164982                              경로         99
# 2286839                        직?단원?출연자         99
# 2293989                        직?단원?출연자         99

# %% [markdown]
# ## 장당금액

# %%
# 장당
5.260000e+07
# Out:
# 52600000.0

# %%
# 위에는 예매에서 봤던데이터

# %%
df[df["장당금액"]>=200000][["좌석수", "공연일시", "예매/취소일시", "입장권고유번호", "예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
# Out:
#          좌석수                공연일시             예매/취소일시                 입장권고유번호  \
# 81340    640 2019-08-03 16:00:00 2019-07-04 22:06:00                    5466
# 102766   978 2019-08-16 15:00:00 2019-07-10 09:06:00         721126122800090
# 102767   978 2019-08-16 15:00:00 2019-07-10 09:06:00         721126122800091
# 535466   686 2019-12-20 19:30:00 2019-11-28 14:37:00         20191128-143737
# 538274   686 2019-12-20 19:30:00 2019-12-17 13:52:00         20191217-135241
# ...      ...                 ...                 ...                     ...
# 1956850  640 2022-07-20 19:30:00 2022-06-07 14:39:00             T1955460053
# 1956913  640 2022-07-20 19:30:00 2022-06-23 17:48:00             T1969226560
# 1956914  640 2022-07-20 19:30:00 2022-06-23 17:48:00             T1969226561
# 1957098  640 2022-07-20 19:30:00 2022-06-29 20:04:00             T1973793190
# 2373625  962 2022-10-26 10:00:00 2022-10-25 17:31:00  2022102501020202001010
#
#           예매/취소금액   할인금액      장당금액                    좌석등급 할인종류명(전송처)  \
# 81340      216750      0    216750    R석(60000), S석(40000)       None
# 102766   10000000      0  10000000  양일권(49500), 일일권(27500)         기타
# 102767   10000000      0  10000000  양일권(49500), 일일권(27500)         기타
# 535466    4720000      0   4720000               전석(20000)       None
# 538274    1573333  66667   1640000               전석(20000)       None
# ...           ...    ...       ...                     ...        ...
# 1956850    287000      0    287000    R석(80000), S석(60000)       None
# 1956913    287000      0    287000    R석(80000), S석(60000)       None
# 1956914    287000      0    287000    R석(80000), S석(60000)       None
# 1957098    287000      0    287000    R석(80000), S석(60000)       None
# 2373625  52600000      0  52600000  1층석(35000), 2층석(25000)       할인없음
#
#         결제수단명(전송처)
# 81340           카드
# 102766          현금
# 102767          현금
# 535466          99
# 538274          99
# ...            ...
# 1956850       신용카드
# 1956913       신용카드
# 1956914       신용카드
# 1957098       신용카드
# 2373625      외상거래처
#
# [286 rows x 10 columns]

# %%
# 할인종류가 명확해서 큰 문제 없음
temp = df[df["장당금액"]>200000][["전송사업자명", "좌석수", "공연일시", "예매/취소일시", "입장권고유번호", "예매/취소금액", "할인금액", "장당금액", "좌석등급", "할인종류명(전송처)", "결제수단명(전송처)"]]
temp = temp[(temp["결제수단명(전송처)"]=="현금")|(temp["결제수단명(전송처)"]=="99")|(temp["할인종류명(전송처)"]=="기타")|(temp["할인종류명(전송처)"]==None)]
temp
# Out:
#           전송사업자명  좌석수                공연일시             예매/취소일시  \
# 102766      예스24  978 2019-08-16 15:00:00 2019-07-10 09:06:00
# 102767      예스24  978 2019-08-16 15:00:00 2019-07-10 09:06:00
# 535466   국립부산국악원  686 2019-12-20 19:30:00 2019-11-28 14:37:00
# 538274   국립부산국악원  686 2019-12-20 19:30:00 2019-12-17 13:52:00
# 1680811   네이버N예약  994 2022-05-13 19:30:00 2022-04-24 18:45:00
# 1680829   네이버N예약  994 2022-05-13 19:30:00 2022-04-25 13:46:00
# 1680833   네이버N예약  994 2022-05-13 19:30:00 2022-04-25 22:57:00
# 1680954   네이버N예약  994 2022-05-13 19:30:00 2022-04-29 20:28:00
# 1680965   네이버N예약  994 2022-05-13 19:30:00 2022-05-01 00:04:00
# 1680975   네이버N예약  994 2022-05-13 19:30:00 2022-05-01 20:00:00
# 1681002   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 09:07:00
# 1681022   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 17:05:00
# 1681023   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 17:05:00
# 1681024   네이버N예약  994 2022-05-13 19:30:00 2022-05-03 17:05:00
# 1681066     인터파크  994 2022-05-13 19:30:00 2022-05-04 12:04:00
# 1681067   네이버N예약  994 2022-05-13 19:30:00 2022-05-04 12:11:00
# 1681123   네이버N예약  994 2022-05-13 19:30:00 2022-05-04 23:21:00
# 1681184   네이버N예약  994 2022-05-13 19:30:00 2022-05-07 21:19:00
# 1681584   네이버N예약  994 2022-05-13 19:30:00 2022-05-12 18:51:00
# 1692946   네이버N예약  994 2022-05-14 18:00:00 2022-04-22 21:54:00
# 1692951   네이버N예약  994 2022-05-14 18:00:00 2022-04-24 00:19:00
# 1692958   네이버N예약  994 2022-05-14 18:00:00 2022-04-25 09:37:00
# 1692962   네이버N예약  994 2022-05-14 18:00:00 2022-04-25 12:32:00
# 1692963   네이버N예약  994 2022-05-14 18:00:00 2022-04-25 12:32:00
# 1692977   네이버N예약  994 2022-05-14 18:00:00 2022-04-27 15:51:00
# 1692978   네이버N예약  994 2022-05-14 18:00:00 2022-04-27 21:06:00
# 1692979   네이버N예약  994 2022-05-14 18:00:00 2022-04-28 09:27:00
# 1692996   네이버N예약  994 2022-05-14 18:00:00 2022-05-03 20:49:00
# 1692997   네이버N예약  994 2022-05-14 18:00:00 2022-05-03 21:24:00
# 1693000   네이버N예약  994 2022-05-14 18:00:00 2022-05-03 22:26:00
# 1693035   네이버N예약  994 2022-05-14 18:00:00 2022-05-07 21:02:00
# 1693036   네이버N예약  994 2022-05-14 18:00:00 2022-05-08 17:48:00
# 1693069   네이버N예약  994 2022-05-14 18:00:00 2022-05-13 15:10:00
#
#                  입장권고유번호   예매/취소금액   할인금액      장당금액                    좌석등급  \
# 102766   721126122800090  10000000      0  10000000  양일권(49500), 일일권(27500)
# 102767   721126122800091  10000000      0  10000000  양일권(49500), 일일권(27500)
# 535466   20191128-143737   4720000      0   4720000               전석(20000)
# 538274   20191217-135241   1573333  66667   1640000               전석(20000)
# 1680811      264227887_0    286000      0    286000  R석(143000), S석(121000)
# 1680829      264495850_0    286000      0    286000  R석(143000), S석(121000)
# 1680833      264722870_0    286000      0    286000  R석(143000), S석(121000)
# 1680954      266577686_0    286000      0    286000  R석(143000), S석(121000)
# 1680965      267096938_0    286000      0    286000  R석(143000), S석(121000)
# 1680975      267429381_0    286000      0    286000  R석(143000), S석(121000)
# 1681002      268104323_0    286000      0    286000  R석(143000), S석(121000)
# 1681022      268347554_0    286000      0    286000  R석(143000), S석(121000)
# 1681023      268347554_1    286000      0    286000  R석(143000), S석(121000)
# 1681024      268347554_2    286000      0    286000  R석(143000), S석(121000)
# 1681066      T1931586370    242000      0    242000  R석(143000), S석(121000)
# 1681067      268676687_0    286000      0    286000  R석(143000), S석(121000)
# 1681123      268997936_0    242000      0    242000  R석(143000), S석(121000)
# 1681184      270376861_0    242000      0    242000  R석(143000), S석(121000)
# 1681584      272626960_0    286000      0    286000  R석(143000), S석(121000)
# 1692946      263542234_0    286000      0    286000  R석(143000), S석(121000)
# 1692951      263973039_0    286000      0    286000  R석(143000), S석(121000)
# 1692958      264372929_0    286000      0    286000  R석(143000), S석(121000)
# 1692962      264457569_0    286000      0    286000  R석(143000), S석(121000)
# 1692963      264457569_1    286000      0    286000  R석(143000), S석(121000)
# 1692977      265487454_0    286000      0    286000  R석(143000), S석(121000)
# 1692978      265643855_0    286000      0    286000  R석(143000), S석(121000)
# 1692979      265782153_0    286000      0    286000  R석(143000), S석(121000)
# 1692996      268443187_2    242000      0    242000  R석(143000), S석(121000)
# 1692997      268456821_0    286000      0    286000  R석(143000), S석(121000)
# 1693000      268481354_0    242000      0    242000  R석(143000), S석(121000)
# 1693035      270372228_0    286000      0    286000  R석(143000), S석(121000)
# 1693036      270645778_0    286000      0    286000  R석(143000), S석(121000)
# 1693069      273040150_0    286000      0    286000  R석(143000), S석(121000)
#
#         할인종류명(전송처) 결제수단명(전송처)
# 102766          기타         현금
# 102767          기타         현금
# 535466        None         99
# 538274        None         99
# 1680811         기타         카드
# 1680829         기타         카드
# 1680833         기타         카드
# 1680954         기타         카드
# 1680965         기타         카드
# 1680975         기타         카드
# 1681002         기타         카드
# 1681022         기타        무통장
# 1681023         기타        무통장
# 1681024         기타        무통장
# 1681066       None         현금
# 1681067         기타         카드
# 1681123         기타         카드
# 1681184         기타         카드
# 1681584         기타         기타
# 1692946         기타         카드
# 1692951         기타         카드
# 1692958         기타         카드
# 1692962         기타         카드
# 1692963         기타         카드
# 1692977         기타         카드
# 1692978         기타         카드
# 1692979         기타         기타
# 1692996         기타         카드
# 1692997         기타         카드
# 1693000         기타        무통장
# 1693035         기타         카드
# 1693036         기타         카드
# 1693069         기타         카드

# %%
# df.to_parquet("After_Medium_Theater.parquet")

# %% [markdown]
# # Make data

# %% [markdown]
# ## 군집분석 데이터(+파생변수)

# %%
df = pd.read_parquet("data/After_Medium_Theater.parquet")

# %%
# 평균좌석점유율 구하기
temp = df[(df["공연일시"]>="2019-07-01")&(df["공연일시"]<"2020-04-01")]
gb = temp.groupby(["공연시설_공연_코드", "공연일시", "좌석수"]).sum()
gb = gb.reset_index()
gb["회차별좌석점유율"] = gb["예매/취소구분"] / gb["좌석수"]
gb = gb.groupby(["공연시설_공연_코드", "좌석수"]).mean().reset_index()
gb = gb[["공연시설_공연_코드", "회차별좌석점유율"]]

# %%
df["평균좌석점유율"] = ""

def MakeAverageSeat (temp, idx, gb):
    for i in idx:
        code = df.iloc[i]["공연시설_공연_코드"]
        temp.loc[i, "평균좌석점유율"] = gb[gb["공연시설_공연_코드"]==code]["회차별좌석점유율"].values[0]
    return temp

idx = temp.index
temp = MakeAverageSeat(temp, idx, gb)
# Out:
# C:\Users\lsj\AppData\Local\Temp\ipykernel_13740\3648638926.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp.loc[i, "평균좌석점유율"] = gb[gb["공연시설_공연_코드"]==code]["회차별좌석점유율"].values[0]

# %%
temp = temp.astype({'평균좌석점유율':'float64'})

# %%
temp = temp.groupby(["공연시설코드", "주소"]).mean()

# %%
temp = temp.reset_index()

# %%
# temp.to_parquet("Medium_Theater_Cluster_adress.parquet")

# %% [markdown]
# ## 군집분석 공연장 수정(전체매출시각화)

# %%
df = pd.read_parquet("data/After_Medium_Theater.parquet")

# %%
cluster = pd.read_parquet("data/Medium_Theater_Cluster_adress.parquet")

# %%
idx = cluster[cluster["무료여부"]==1].index

cluster = cluster.drop(idx, axis=0)
cluster = cluster.reset_index(drop=True)

# %%
len(cluster["공연시설코드"].unique())
# Out:
# 177

# %%
len(df["공연시설코드"].unique())
# Out:
# 222

# %%
code = cluster["공연시설코드"].tolist()

# %%
len(df[df["공연시설코드"].apply(lambda x : x in code)])
# Out:
# 2603642

# %%
len(df)
# Out:
# 2785422

# %%
df = df[df["공연시설코드"].apply(lambda x : x in code)]

# %%
len(df["공연시설코드"].unique())
# Out:
# 177

# %%
temp = df.groupby(["공연시설코드", "년도_월"]).mean()

# %%
temp = temp.reset_index()[["공연시설코드", "년도_월", "예매/취소금액"]]

# %%
idx = temp["공연시설코드"].unique()
len(idx)
# Out:
# 177

# %%
# 충격지점 이후 0이 아닌 데이터가 2개이상인 극장만 선정
res = []
cnt = 1
for i in range(len(idx)):
    draw_df = temp[temp["공연시설코드"]==idx[i]]
    data_after_time_point = draw_df[(draw_df["년도_월"] >= 202004)&(draw_df["년도_월"] <= 202212)][["예매/취소금액"]]
    data_after_time_point_len = len(data_after_time_point)

    if (data_after_time_point_len <= 1):
        res.append(idx[i])
    else:
        for j in range(data_after_time_point_len):
            if data_after_time_point.iloc[j].values[0] != 0:
                cnt = cnt+1
        if cnt == 1:
            res.append(idx[i])
    cnt=1

# %%
idx = cluster[cluster["공연시설코드"].apply(lambda x : x in res)].index
idx
# Out:
# Int64Index([  7,  31,  37,  41,  42,  51,  52,  65,  66,  71,  78,  89,  92,
#             100, 107, 108, 110, 124, 134, 138, 139, 146, 150, 153, 157, 159,
#             161, 162, 163, 165, 166, 168, 169, 170, 171, 173, 174, 175, 176],
#            dtype='int64')

# %%
cluster = cluster.drop(idx, axis=0)
cluster = cluster.reset_index(drop=True)

# %%
idx = temp[temp["공연시설코드"].apply(lambda x : x in res)].index
idx
# Out:
# Int64Index([ 169,  170,  713,  714,  715,  716,  717,  718,  719,  861,
#             ...
#             2861, 2862, 2863, 2864, 2865, 2874, 2875, 2876, 2877, 2878],
#            dtype='int64', length=102)

# %%
temp = temp.drop(idx, axis=0)
temp = temp.reset_index(drop=True)

# %%
idx = temp["공연시설코드"].unique()
len(idx)
# Out:
# 138

# %%
idx = cluster["공연시설코드"].unique()
len(idx)
# Out:
# 138

# %%
# cluster.to_parquet("Medium_Theater_remove_cluster.parquet")

# %%
# cluster.to_csv("Medium_Theater_remove_cluster.csv")

# %% [markdown]
# ## 예상매출 학습 데이터

# %%
df = pd.read_parquet("data/After_Medium_Theater.parquet")

# %%
temp = df[(df["공연일시"]>="2019-07-01")&(df["공연일시"]<"2020-04-01")]
temp = temp.groupby(["공연시설코드", "년도_월", "좌석수", "년도_월_일"]).sum()

# %%
temp = temp.reset_index()[["공연시설코드", "년도_월", "년도_월_일", "좌석수", "예매/취소금액", "예매/취소구분"]]

# %%
cluster = pd.read_parquet("data/Medium_Theater_remove_cluster.parquet")

# %%
len(cluster["공연시설코드"].unique())
# Out:
# 138

# %%
len(temp["공연시설코드"].unique())
# Out:
# 186

# %%
code = cluster["공연시설코드"].tolist()

# %%
len(temp[temp["공연시설코드"].apply(lambda x : x in code)])
# Out:
# 2578

# %%
temp = temp[temp["공연시설코드"].apply(lambda x : x in code)]

# %%
len(temp["공연시설코드"].unique())
# Out:
# 138

# %%
idx = temp["공연시설코드"].unique()
len(idx)
# Out:
# 138

# %%
# temp.to_csv("Medium_Theater_estimate.csv", index=False)

# %% [markdown]
# ## 회복탄력성 데이터

# %%
# 군집분석 공연시설과 기간이 다르기 때문에 군집분석 데이터 기준으로 공연시설코드 통일시켜주기

# %%
df = pd.read_parquet("data/After_Medium_Theater.parquet")

# %%
temp = df[(df["공연일시"] >= "2020-04-01")&(df["공연일시"] < "2023-01-01")]
temp = temp.groupby(["공연시설코드", "년도_월"]).sum()
temp
# Out:
#                     좌석수  예매/취소구분   예매/취소금액  예매/취소방식코드  결제수단코드    할인금액  할인종류코드  \
# 공연시설코드   년도_월
# FC222006 202208   22365       45    350000         87     682       0    4455
#          202209   23359       47    221000         84    2044       0    4653
# FC222007 202103    8256       16    234000         22     526   30000    1584
#          202105  243036      471   9572500        853   13501       0   46629
#          202106     516        1     10000          1       2       0      99
# ...                 ...      ...       ...        ...     ...     ...     ...
# FC225265 202210  238640      628  11609200       2414   14518       0   62172
#          202211  394440     1038  20810879      12780   34765       0  102762
#          202212  145920      384   6912000        721   22607       0   38016
# FC225327 202209   60000      200         0      16373     204       0   19800
# FC225373 202212  279900      933  31158400       1670   60810  437600   92367
#
#                      장당금액        년도_월_일       년도      월      일  예매건수  취소건수  \
# 공연시설코드   년도_월
# FC222006 202208    350000  9.099365e+08    90990    360    526    45     0
#          202209    221000  9.503837e+08    95034    423   1382    47     0
# FC222007 202103    264000  3.233653e+08    32336     48    480    16     0
#          202105   9572500  9.519150e+09   951891   2355   4029   471     0
#          202106     10000  2.021062e+07     2021      6     24     1     0
# ...                   ...           ...      ...    ...    ...   ...   ...
# FC225265 202210  11609200  1.269880e+10  1269816   6280   7278   628     0
#          202211  20810879  2.098952e+10  2098836  11418  18455  1038     0
#          202212   6912000  7.764950e+09   776448   4608   9216   384     0
# FC225327 202209         0  4.044181e+09   404400   1800    600   200     0
# FC225373 202212  31596000  1.886640e+10  1886526  11196  21678   933     0
#
#                  무료여부
# 공연시설코드   년도_월
# FC222006 202208    90
#          202209    94
# FC222007 202103    32
#          202105   942
#          202106     2
# ...               ...
# FC225265 202210  1256
#          202211  2076
#          202212   768
# FC225327 202209   200
# FC225373 202212  1866
#
# [2390 rows x 15 columns]

# %%
temp = temp.reset_index()
temp = temp[["공연시설코드", "년도_월", "예매/취소금액"]]

# %%
len(temp["공연시설코드"].unique())
# Out:
# 193

# %%
cluster = pd.read_parquet("data/Medium_Theater_remove_cluster.parquet")

# %%
len(cluster["공연시설코드"].unique())
# Out:
# 138

# %%
len(temp["공연시설코드"].unique())
# Out:
# 193

# %%
code = cluster["공연시설코드"].tolist()

# %%
len(temp[temp["공연시설코드"].apply(lambda x : x in code)])
# Out:
# 2119

# %%
temp = temp[temp["공연시설코드"].apply(lambda x : x in code)]

# %%
len(temp["공연시설코드"].unique())
# Out:
# 138

# %%
temp = temp.reset_index(drop=True)

# %%
# temp.to_csv("Medium_Theater_resilience.csv", index=False)
